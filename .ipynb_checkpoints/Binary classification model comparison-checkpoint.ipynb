# %% [markdown]
# In this notebook, I will compare several binary classification models using a simulated dataset.

# %% [markdown]
# The data is simulated using scikit-learn's ```make_classification```. First, the models will be trained and tested on a simple dataset with 2 relevant features. Later, they will be trained and tested on a more complex dataset with both redundant and repeated features without any feature engineering. ```make_classification``` documentation can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).

# %% [markdown]
# I will try the following scikit-learn classifiers (click on the model name for documentation): [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html),
# [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html),
# [LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html),
# [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html),
# [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html).

# %% [markdown]
# I will also add multiplayer perceptrons in Keras and PyTorch and evaluate their performances.

# %%
# create simulated data with 2 features
from sklearn.datasets import make_classification

X, Y = make_classification(n_samples = 1000,
                           n_features = 2,
                           n_informative = 2,
                           n_redundant = 0,
                           n_clusters_per_class = 1,
                           random_state = 47)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 47)

# %%
# plot the training data
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()

# %%
# import the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# fit logistic regression with default parameters
log_reg = LogisticRegression()
log_reg.fit(X_train, Y_train)
# obtain prediction accuracy on test data 
log_reg.score(X_test, Y_test)
# Out:
# 0.928

# %%
# fit the decision tree classifier with default parameters
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, Y_train)
# obtain prediction accuracy on test data
dt_clf.score(X_test, Y_test)
# Out:
# 0.944

# %%
# fit linear SVC with default parameters
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
# obtain prediction accuracy on test data
linear_svc.score(X_test, Y_test)
# Out:
# 0.928

# %%
# fit K-neighbors classifier with default parameters
kn_clf = KNeighborsClassifier()
kn_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
kn_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# fit the random forrest classifier with default parameters
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
rf_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# fit the gradient boosting classifier with default parameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
gb_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# %%time
# create a binary classification model in Keras
from keras.models import Sequential
from keras.layers import Dense

# three layer model with 2 feature input and sigmoid output
model = Sequential([
    Dense(30, input_shape=(2,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model.fit(X_train, Y_train, epochs = 50)
# evaluate using the test data
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6445 - binary_accuracy: 0.7733
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5116 - binary_accuracy: 0.9013
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3982 - binary_accuracy: 0.9080
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3118 - binary_accuracy: 0.9173
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2573 - binary_accuracy: 0.9280
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2273 - binary_accuracy: 0.9267
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2150 - binary_accuracy: 0.9267
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2109 - binary_accuracy: 0.9320
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2085 - binary_accuracy: 0.9280
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2034 - binary_accuracy: 0.9280
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2010 - binary_accuracy: 0.9280
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2001 - binary_accuracy: 0.9293
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1987 - binary_accuracy: 0.9267
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1976 - binary_accuracy: 0.9267
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1967 - binary_accuracy: 0.9267
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1961 - binary_accuracy: 0.9280
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1947 - binary_accuracy: 0.9280
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1934 - binary_accuracy: 0.9293
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1925 - binary_accuracy: 0.9293
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1921 - binary_accuracy: 0.9333
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1910 - binary_accuracy: 0.9320
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1894 - binary_accuracy: 0.9347
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1899 - binary_accuracy: 0.9307
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1876 - binary_accuracy: 0.9360
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1871 - binary_accuracy: 0.9320
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1851 - binary_accuracy: 0.9307
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1856 - binary_accuracy: 0.9320
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1850 - binary_accuracy: 0.9347
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1837 - binary_accuracy: 0.9307
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1832 - binary_accuracy: 0.9347
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1816 - binary_accuracy: 0.9347
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1809 - binary_accuracy: 0.9320
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1801 - binary_accuracy: 0.9360
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1799 - binary_accuracy: 0.9333
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1787 - binary_accuracy: 0.9320
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1785 - binary_accuracy: 0.9360
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1775 - binary_accuracy: 0.9347
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1774 - binary_accuracy: 0.9360
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1775 - binary_accuracy: 0.9347
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1767 - binary_accuracy: 0.9360
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1767 - binary_accuracy: 0.9320
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1745 - binary_accuracy: 0.9360
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1754 - binary_accuracy: 0.9373
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1743 - binary_accuracy: 0.9373
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1749 - binary_accuracy: 0.9360
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1746 - binary_accuracy: 0.9347
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1727 - binary_accuracy: 0.9347
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1723 - binary_accuracy: 0.9373
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1722 - binary_accuracy: 0.9373
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1738 - binary_accuracy: 0.9347
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1515 - binary_accuracy: 0.9480
# Wall time: 10.1 s
# [0.1514817476272583, 0.9480000138282776]

# %%
# create a binary classification model in PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

class TorchBinaryClassifier(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(2, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net = TorchBinaryClassifier()

# %%
# specify loss and optimizer
import torch.optim as optim

criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

X_train_tensor = torch.from_numpy(X_train).float()
Y_train_tensor = torch.from_numpy(Y_train).float().squeeze()

X_test_tensor = torch.from_numpy(X_test).float()
Y_test_tensor = torch.from_numpy(Y_test).float()

trainset = TensorDataset(X_train_tensor, Y_train_tensor)
testset = TensorDataset(X_test_tensor, Y_test_tensor)

train_loader = DataLoader(trainset)
test_loader = DataLoader(testset)

# %%
# %%time
# train the model
net.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader:
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader.dataset)}')
# Out:
# Epoch: 1, training loss: 0.2958946033414686
# Epoch: 2, training loss: 0.20286929394548253
# Epoch: 3, training loss: 0.19402984551987418
# Epoch: 4, training loss: 0.18820948202426857
# Epoch: 5, training loss: 0.18537528111120144
# Epoch: 6, training loss: 0.1814583851692587
# Epoch: 7, training loss: 0.1776432290566736
# Epoch: 8, training loss: 0.17465672289964762
# Epoch: 9, training loss: 0.1719175174380689
# Epoch: 10, training loss: 0.16948606218162726
# Epoch: 11, training loss: 0.16715320675355239
# Epoch: 12, training loss: 0.16503746489194904
# Epoch: 13, training loss: 0.16336941931636464
# Epoch: 14, training loss: 0.16174720671110784
# Epoch: 15, training loss: 0.16091872904934948
# Epoch: 16, training loss: 0.15922589107048893
# Epoch: 17, training loss: 0.15815160551692195
# Epoch: 18, training loss: 0.15718770325442408
# Epoch: 19, training loss: 0.15648447739019927
# Epoch: 20, training loss: 0.1555834251620472
# Epoch: 21, training loss: 0.1548801422462966
# Epoch: 22, training loss: 0.15420432607614445
# Epoch: 23, training loss: 0.15339428759789492
# Epoch: 24, training loss: 0.1528493151429575
# Epoch: 25, training loss: 0.1523775904119878
# Epoch: 26, training loss: 0.15167087276618502
# Epoch: 27, training loss: 0.1511659274373766
# Epoch: 28, training loss: 0.15072694978843598
# Epoch: 29, training loss: 0.15034294673578308
# Epoch: 30, training loss: 0.1496757980529413
# Epoch: 31, training loss: 0.14890287296433236
# Epoch: 32, training loss: 0.14850307282248104
# Epoch: 33, training loss: 0.14813066129136618
# Epoch: 34, training loss: 0.14775810021615568
# Epoch: 35, training loss: 0.14740535846153702
# Epoch: 36, training loss: 0.1466547623474956
# Epoch: 37, training loss: 0.14616766480175525
# Epoch: 38, training loss: 0.14609889166766274
# Epoch: 39, training loss: 0.1455041520161855
# Epoch: 40, training loss: 0.14542856213296182
# Epoch: 41, training loss: 0.1448467766227089
# Epoch: 42, training loss: 0.14452750582995214
# Epoch: 43, training loss: 0.14526034208553512
# Epoch: 44, training loss: 0.14410025510567842
# Epoch: 45, training loss: 0.14393893875806923
# Epoch: 46, training loss: 0.1434609854488408
# Epoch: 47, training loss: 0.14339627142515504
# Epoch: 48, training loss: 0.14252748792602385
# Epoch: 49, training loss: 0.14216949976911686
# Epoch: 50, training loss: 0.1417249639001408
# Wall time: 37.9 s

# %%
# evaluate the model
import numpy as np

net.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader:
    output = net(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
print(f'Loss: {test_loss/len(test_loader.dataset)}')
print(f'Accuracy: {correct_predictions/len(test_loader.dataset)}')
# Out:
# Loss: 0.13307546862470918
# Accuracy: 0.952

# %% [markdown]
# All models achieved above 90% accuracy. The PyTorch MLP required by far the most lines of code and was the slowest.

# %% [markdown]
# Now I will test the same models on a dataset with 4 features, 3 of which are informative, and one is a random linear combination of the others.

# %%
X_2, Y_2 = make_classification(n_samples = 1000,
                           n_features = 4,
                           n_informative = 3,
                           n_redundant = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2, Y_2, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# display the new classes in terms of the first 3 features using an interactive 3d plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_2_train[:,0], X_2_train[:,1], X_2_train[:,2], c = Y_2_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# fit and evaluate logistic regression
log_reg.fit(X_2_train, Y_2_train)
log_reg.score(X_2_test, Y_2_test)
# Out:
# 0.928

# %%
# fit and evaluate the decision tree classifier
dt_clf.fit(X_2_train, Y_2_train)
dt_clf.score(X_2_test, Y_2_test)
# Out:
# 0.912

# %%
# fit and evaluate linear SVC
linear_svc.fit(X_2_train, Y_2_train)
linear_svc.score(X_2_test, Y_2_test)
# Out:
# 0.928

# %%
# fit and evaluate K-neighbors classifier
kn_clf.fit(X_2_train, Y_2_train)
kn_clf.score(X_2_test, Y_2_test)
# Out:
# 0.944

# %%
# fit and evaluate the random forrest classifier
rf_clf.fit(X_2_train, Y_2_train)
rf_clf.score(X_2_test, Y_2_test)
# Out:
# 0.94

# %%
# fit and evaluate the gradient boosting classifier
gb_clf.fit(X_2_train, Y_2_train)
gb_clf.score(X_2_test, Y_2_test)
# Out:
# 0.948

# %%
# %%time
# three layer model with 4 feature input and sigmoid output
model_2 = Sequential([
    Dense(30, input_shape=(4,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model_2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model_2.fit(X_2_train, Y_2_train, epochs = 50)
# evaluate using the test data
model_2.evaluate(X_2_test, Y_2_test)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5531 - binary_accuracy: 0.8147
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3667 - binary_accuracy: 0.9160
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2712 - binary_accuracy: 0.9293
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2285 - binary_accuracy: 0.9320
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2065 - binary_accuracy: 0.9267
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1961 - binary_accuracy: 0.9293
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1904 - binary_accuracy: 0.9360
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1862 - binary_accuracy: 0.9333
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1831 - binary_accuracy: 0.9307
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1803 - binary_accuracy: 0.9333
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1794 - binary_accuracy: 0.9333
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1772 - binary_accuracy: 0.9280
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1754 - binary_accuracy: 0.9293
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1742 - binary_accuracy: 0.9293
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1730 - binary_accuracy: 0.9293
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1709 - binary_accuracy: 0.9307
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1704 - binary_accuracy: 0.9293
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1701 - binary_accuracy: 0.9333
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1676 - binary_accuracy: 0.9333
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1688 - binary_accuracy: 0.9400
# Epoch 21/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1664 - binary_accuracy: 0.9333
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1667 - binary_accuracy: 0.9333
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1642 - binary_accuracy: 0.9347
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1639 - binary_accuracy: 0.9347
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1629 - binary_accuracy: 0.9373
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1621 - binary_accuracy: 0.9373
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1627 - binary_accuracy: 0.9333
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1605 - binary_accuracy: 0.9373
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1596 - binary_accuracy: 0.9373
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1592 - binary_accuracy: 0.9373
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1601 - binary_accuracy: 0.9387
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1572 - binary_accuracy: 0.9413
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1570 - binary_accuracy: 0.9373
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1562 - binary_accuracy: 0.9413
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1557 - binary_accuracy: 0.9400
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1545 - binary_accuracy: 0.9427
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1537 - binary_accuracy: 0.9427
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1543 - binary_accuracy: 0.9440
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1530 - binary_accuracy: 0.9440
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1522 - binary_accuracy: 0.9440
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1520 - binary_accuracy: 0.9440
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1513 - binary_accuracy: 0.9427
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1511 - binary_accuracy: 0.9467
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1496 - binary_accuracy: 0.9440
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1487 - binary_accuracy: 0.9453
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1484 - binary_accuracy: 0.9467
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1483 - binary_accuracy: 0.9440
# Epoch 48/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1475 - binary_accuracy: 0.9453
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1468 - binary_accuracy: 0.9480
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1460 - binary_accuracy: 0.9467
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1597 - binary_accuracy: 0.9480
# Wall time: 2.71 s
# [0.1596599519252777, 0.9480000138282776]

# %%
# create another binary classification model in PyTorch
class TorchBinaryClassifier_2(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier_2, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(4, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net_2 = TorchBinaryClassifier_2()

# %%
# specify loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(net_2.parameters())

# %%
# speficy train and test data
X_2_train_tensor = torch.from_numpy(X_2_train).float()
Y_2_train_tensor = torch.from_numpy(Y_2_train).float().squeeze()

X_2_test_tensor = torch.from_numpy(X_2_test).float()
Y_2_test_tensor = torch.from_numpy(Y_2_test).float()

trainset_2 = TensorDataset(X_2_train_tensor, Y_2_train_tensor)
testset_2 = TensorDataset(X_2_test_tensor, Y_2_test_tensor)

train_loader_2 = DataLoader(trainset_2)
test_loader_2 = DataLoader(testset_2)

# %%
# %%time
# train the model
net_2.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader_2:
        optimizer.zero_grad()
        output = net_2(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader_2.dataset)}')
# Out:
# Epoch: 1, training loss: 0.25482820415662827
# Epoch: 2, training loss: 0.1903875055842509
# Epoch: 3, training loss: 0.1831746830192692
# Epoch: 4, training loss: 0.17772167281054932
# Epoch: 5, training loss: 0.17338337982162563
# Epoch: 6, training loss: 0.17022204113911413
# Epoch: 7, training loss: 0.16785543440347864
# Epoch: 8, training loss: 0.1660702748255436
# Epoch: 9, training loss: 0.1643239457083409
# Epoch: 10, training loss: 0.16277621649978471
# Epoch: 11, training loss: 0.1617339701695382
# Epoch: 12, training loss: 0.16021514299388168
# Epoch: 13, training loss: 0.15879988566822958
# Epoch: 14, training loss: 0.15717199220726763
# Epoch: 15, training loss: 0.15616257369812425
# Epoch: 16, training loss: 0.15500772052039713
# Epoch: 17, training loss: 0.1540589620977319
# Epoch: 18, training loss: 0.15314150582209382
# Epoch: 19, training loss: 0.15141825765298472
# Epoch: 20, training loss: 0.1502166555973413
# Epoch: 21, training loss: 0.14914556088552658
# Epoch: 22, training loss: 0.14803259578911165
# Epoch: 23, training loss: 0.1471778504301005
# Epoch: 24, training loss: 0.14611315553160162
# Epoch: 25, training loss: 0.14497858961270357
# Epoch: 26, training loss: 0.1438270744878366
# Epoch: 27, training loss: 0.143047421412126
# Epoch: 28, training loss: 0.14185615317825187
# Epoch: 29, training loss: 0.14125784481546552
# Epoch: 30, training loss: 0.1400767134773038
# Epoch: 31, training loss: 0.13938136491978373
# Epoch: 32, training loss: 0.13835681406181613
# Epoch: 33, training loss: 0.13763548065078163
# Epoch: 34, training loss: 0.13646944358648608
# Epoch: 35, training loss: 0.13613438429080474
# Epoch: 36, training loss: 0.13496666895365533
# Epoch: 37, training loss: 0.13462299009915632
# Epoch: 38, training loss: 0.13365173337263545
# Epoch: 39, training loss: 0.132487190198066
# Epoch: 40, training loss: 0.13259907297922283
# Epoch: 41, training loss: 0.13159423015834368
# Epoch: 42, training loss: 0.1309702546062824
# Epoch: 43, training loss: 0.1298736896815739
# Epoch: 44, training loss: 0.12932094295388957
# Epoch: 45, training loss: 0.12817022688043386
# Epoch: 46, training loss: 0.12827605707543124
# Epoch: 47, training loss: 0.1269358606217797
# Epoch: 48, training loss: 0.12810840264012402
# Epoch: 49, training loss: 0.12645471085869767
# Epoch: 50, training loss: 0.1261887531733805
# Wall time: 38.2 s

# %%
# evaluate the model
net_2.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader_2:
    output = net_2(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
print(f'Loss: {test_loss/len(test_loader_2.dataset)}')
print(f'Accuracy: {correct_predictions/len(test_loader_2.dataset)}')
# Out:
# Loss: 0.13310971710342767
# Accuracy: 0.948

# %% [markdown]
# All models achieved over 90% accuracy again.

# %% [markdown]
# For the next dataset, I will use 7 features broken down into 4 informative, 2 redundant (linear combinations of informative features), and 1 repeated (randomly chosen from the previous 6).

# %%
X_3, Y_3 = make_classification(n_samples = 1000,
                           n_features = 7,
                           n_informative = 4,
                           n_redundant = 2,
                           n_repeated = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_3_train, X_3_test, Y_3_train, Y_3_test = train_test_split(X_3, Y_3, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# fit and evaluate logistic regression
log_reg.fit(X_3_train, Y_3_train)
log_reg.score(X_3_test, Y_3_test)
# Out:
# 0.884

# %%
# fit and evaluate the decision tree classifier
dt_clf.fit(X_3_train, Y_3_train)
dt_clf.score(X_3_test, Y_3_test)
# Out:
# 0.868

# %%
# fit and evaluate linear SVC
linear_svc.fit(X_3_train, Y_3_train)
linear_svc.score(X_3_test, Y_3_test)
# Out:
# C:\Users\metal\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.88

# %%
# fit and evaluate K-neighbors classifier
kn_clf.fit(X_3_train, Y_3_train)
kn_clf.score(X_3_test, Y_3_test)
# Out:
# 0.9

# %%
# fit and evaluate the random forrest classifier
rf_clf.fit(X_3_train, Y_3_train)
rf_clf.score(X_3_test, Y_3_test)
# Out:
# 0.904

# %%
# fit and evaluate the gradient boosting classifier
gb_clf.fit(X_3_train, Y_3_train)
gb_clf.score(X_3_test, Y_3_test)
# Out:
# 0.892

# %%
# %%time
# three layer model with 4 feature input and sigmoid output
model_3 = Sequential([
    Dense(30, input_shape=(7,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model_3.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model_3.fit(X_3_train, Y_3_train, epochs = 50)
# evaluate using the test data
model_3.evaluate(X_3_test, Y_3_test)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5670 - binary_accuracy: 0.6933
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4411 - binary_accuracy: 0.8333
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3517 - binary_accuracy: 0.8867
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2803 - binary_accuracy: 0.9093
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2397 - binary_accuracy: 0.9173
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2185 - binary_accuracy: 0.9213
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2069 - binary_accuracy: 0.9240
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2007 - binary_accuracy: 0.9173
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1981 - binary_accuracy: 0.9213
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1936 - binary_accuracy: 0.9227
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1897 - binary_accuracy: 0.9280
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1886 - binary_accuracy: 0.9253
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1872 - binary_accuracy: 0.9267
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1845 - binary_accuracy: 0.9280
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1838 - binary_accuracy: 0.9240
# Epoch 16/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1821 - binary_accuracy: 0.9280
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1811 - binary_accuracy: 0.9307
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1811 - binary_accuracy: 0.9253
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1784 - binary_accuracy: 0.9253
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1769 - binary_accuracy: 0.9293
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1757 - binary_accuracy: 0.9267
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1749 - binary_accuracy: 0.9307
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1740 - binary_accuracy: 0.9293
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1732 - binary_accuracy: 0.9227
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1738 - binary_accuracy: 0.9373
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1714 - binary_accuracy: 0.9280
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1697 - binary_accuracy: 0.9293
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1703 - binary_accuracy: 0.9267
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1701 - binary_accuracy: 0.9267
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1697 - binary_accuracy: 0.9253
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1681 - binary_accuracy: 0.9307
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1672 - binary_accuracy: 0.9293
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1662 - binary_accuracy: 0.9280
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1665 - binary_accuracy: 0.9293
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1673 - binary_accuracy: 0.9267
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1641 - binary_accuracy: 0.9307
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1643 - binary_accuracy: 0.9280
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1640 - binary_accuracy: 0.9320
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1631 - binary_accuracy: 0.9320
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1650 - binary_accuracy: 0.9240
# Epoch 41/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0930 - binary_accuracy: 0.968 - 0s 1ms/step - loss: 0.1616 - binary_accuracy: 0.9280
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1616 - binary_accuracy: 0.9253
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1605 - binary_accuracy: 0.9267
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1602 - binary_accuracy: 0.9347
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1601 - binary_accuracy: 0.9267
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1605 - binary_accuracy: 0.9307
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1588 - binary_accuracy: 0.9293
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1606 - binary_accuracy: 0.9240
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1607 - binary_accuracy: 0.9360
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1621 - binary_accuracy: 0.9253
# 8/8 [==============================] - 0s 0s/step - loss: 0.2203 - binary_accuracy: 0.9080
# Wall time: 2.58 s
# [0.22029337286949158, 0.9079999923706055]

# %%
# create another binary classification model in PyTorch
class TorchBinaryClassifier_3(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier_3, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(7, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net_3 = TorchBinaryClassifier_3()

# %%
# specify loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(net_3.parameters())

# %%
# speficy train and test data
X_3_train_tensor = torch.from_numpy(X_3_train).float()
Y_3_train_tensor = torch.from_numpy(Y_3_train).float().squeeze()

X_3_test_tensor = torch.from_numpy(X_3_test).float()
Y_3_test_tensor = torch.from_numpy(Y_3_test).float()

trainset_3 = TensorDataset(X_3_train_tensor, Y_3_train_tensor)
testset_3 = TensorDataset(X_3_test_tensor, Y_3_test_tensor)

train_loader_3 = DataLoader(trainset_3)
test_loader_3 = DataLoader(testset_3)

# %%
# %%time
# train the model
net_3.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader_3:
        optimizer.zero_grad()
        output = net_3(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader_3.dataset)}')
# Out:
# Epoch: 1, training loss: 0.3527187205848944
# Epoch: 2, training loss: 0.21741171252066852
# Epoch: 3, training loss: 0.20057690633759193
# Epoch: 4, training loss: 0.19341134839260485
# Epoch: 5, training loss: 0.18886985951621985
# Epoch: 6, training loss: 0.18607496484013064
# Epoch: 7, training loss: 0.18398697900583103
# Epoch: 8, training loss: 0.18226045949411962
# Epoch: 9, training loss: 0.1810419260220383
# Epoch: 10, training loss: 0.17968263285644706
# Epoch: 11, training loss: 0.17870975507566103
# Epoch: 12, training loss: 0.17719055928508556
# Epoch: 13, training loss: 0.17662903765972554
# Epoch: 14, training loss: 0.17540930741551536
# Epoch: 15, training loss: 0.17445526416725307
# Epoch: 16, training loss: 0.17300809273544338
# Epoch: 17, training loss: 0.17217805229750557
# Epoch: 18, training loss: 0.1710609002424369
# Epoch: 19, training loss: 0.16982687470327418
# Epoch: 20, training loss: 0.16846153752282123
# Epoch: 21, training loss: 0.16790813730540322
# Epoch: 22, training loss: 0.16632306692021787
# Epoch: 23, training loss: 0.16577582421830833
# Epoch: 24, training loss: 0.16458964036469023
# Epoch: 25, training loss: 0.1640647629431764
# Epoch: 26, training loss: 0.16305027236740036
# Epoch: 27, training loss: 0.16203296402058442
# Epoch: 28, training loss: 0.16072525158308987
# Epoch: 29, training loss: 0.16004291920566727
# Epoch: 30, training loss: 0.1584485321181625
# Epoch: 31, training loss: 0.15806289751533803
# Epoch: 32, training loss: 0.15703663219495842
# Epoch: 33, training loss: 0.15561082805718968
# Epoch: 34, training loss: 0.15569913511366207
# Epoch: 35, training loss: 0.1543646794227369
# Epoch: 36, training loss: 0.15351412965452665
# Epoch: 37, training loss: 0.1524329691480241
# Epoch: 38, training loss: 0.1518484176362656
# Epoch: 39, training loss: 0.15204805852660933
# Epoch: 40, training loss: 0.15100489507004664
# Epoch: 41, training loss: 0.1499363834992311
# Epoch: 42, training loss: 0.14919076397668246
# Epoch: 43, training loss: 0.1477801957829361
# Epoch: 44, training loss: 0.1468878591621107
# Epoch: 45, training loss: 0.1451802552398988
# Epoch: 46, training loss: 0.14470815639422502
# Epoch: 47, training loss: 0.1439222160532773
# Epoch: 48, training loss: 0.14347023420995383
# Epoch: 49, training loss: 0.14278095734063437
# Epoch: 50, training loss: 0.14237901132861763
# Wall time: 37.6 s

# %%
# evaluate the model
net_3.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader_3:
    output = net_3(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
print(f'Loss: {test_loss/len(test_loader_3.dataset)}')
print(f'Accuracy: {correct_predictions/len(test_loader_3.dataset)}')
# Out:
# Loss: 0.23150770526119288
# Accuracy: 0.916

# %% [markdown]
# The next dataset will consist of 10 features with the following breakdown: 5 informative, 3 redundant, 2 repeated.

# %%
X_4, Y_4 = make_classification(n_samples = 1000,
                           n_features = 10,
                           n_informative = 5,
                           n_redundant = 3,
                           n_repeated = 2,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_4_train, X_4_test, Y_4_train, Y_4_test = train_test_split(X_4, Y_4, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# fit and evaluate logistic regression
log_reg.fit(X_4_train, Y_4_train)
log_reg.score(X_4_test, Y_4_test)
# Out:
# 0.88

# %%
# fit and evaluate the decision tree classifier
dt_clf.fit(X_4_train, Y_4_train)
dt_clf.score(X_4_test, Y_4_test)
# Out:
# 0.92

# %%
# fit and evaluate linear SVC
linear_svc.fit(X_4_train, Y_4_train)
linear_svc.score(X_4_test, Y_4_test)
# Out:
# C:\Users\metal\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.88

# %%
# fit and evaluate K-neighbors classifier
kn_clf.fit(X_4_train, Y_4_train)
kn_clf.score(X_4_test, Y_4_test)
# Out:
# 0.956

# %%
# fit and evaluate the random forrest classifier
rf_clf.fit(X_4_train, Y_4_train)
rf_clf.score(X_4_test, Y_4_test)
# Out:
# 0.948

# %%
# fit and evaluate the gradient boosting classifier
gb_clf.fit(X_4_train, Y_4_train)
gb_clf.score(X_4_test, Y_4_test)
# Out:
# 0.952
