# %% [markdown]
# In this notebook, I will compare several binary classification models using a simulated dataset.

# %% [markdown]
# The data is simulated using scikit-learn's ```make_classification```. First, the models will be trained and tested on a simple dataset with 2 relevant features. Later, they will be trained and tested on a more complex dataset with both redundant and repeated features without any feature engineering. ```make_classification``` documentation can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).

# %% [markdown]
# I will try the following scikit-learn classifiers (click on the model name for documentation): [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html),
# [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html),
# [LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html),
# [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html),
# [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html).

# %% [markdown]
# I will also add multiplayer perceptrons in Keras and PyTorch and evaluate their performances.

# %%
# create simulated data with 2 features
from sklearn.datasets import make_classification

X, Y = make_classification(n_samples = 1000,
                           n_features = 2,
                           n_informative = 2,
                           n_redundant = 0,
                           n_clusters_per_class = 1,
                           random_state = 47)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 47)

# %%
# plot the training data
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()

# %%
# import the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# fit logistic regression with default parameters
log_reg = LogisticRegression()
log_reg.fit(X_train, Y_train)
# obtain prediction accuracy on test data 
log_reg.score(X_test, Y_test)
# Out:
# 0.928

# %%
# fit the decision tree classifier with default parameters
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, Y_train)
# obtain prediction accuracy on test data
dt_clf.score(X_test, Y_test)
# Out:
# 0.936

# %%
# fit linear SVC with default parameters
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
# obtain prediction accuracy on test data
linear_svc.score(X_test, Y_test)
# Out:
# 0.928

# %%
# fit K-neighbors classifier with default parameters
kn_clf = KNeighborsClassifier()
kn_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
kn_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# fit the random forrest classifier with default parameters
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
rf_clf.score(X_test, Y_test)
# Out:
# 0.948

# %%
# fit the gradient boosting classifier with default parameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
gb_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# %%time
# create a binary classification model in Keras
from keras.models import Sequential
from keras.layers import Dense

# three layer model with 2 feature input and sigmoid output
model = Sequential([
    Dense(30, input_shape=(2,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model.fit(X_train, Y_train, epochs = 50)
# evaluate using the test data
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6144 - binary_accuracy: 0.8227
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4941 - binary_accuracy: 0.9293
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3825 - binary_accuracy: 0.9213
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2917 - binary_accuracy: 0.9200
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2412 - binary_accuracy: 0.9253
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2171 - binary_accuracy: 0.9280
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2081 - binary_accuracy: 0.9280
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2040 - binary_accuracy: 0.9307
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2028 - binary_accuracy: 0.9280
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2009 - binary_accuracy: 0.9293
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1985 - binary_accuracy: 0.9293
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1965 - binary_accuracy: 0.9293
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1960 - binary_accuracy: 0.9253
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1944 - binary_accuracy: 0.9333
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1938 - binary_accuracy: 0.9333
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1905 - binary_accuracy: 0.9333
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1894 - binary_accuracy: 0.9307
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1883 - binary_accuracy: 0.9320
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1867 - binary_accuracy: 0.9307
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1858 - binary_accuracy: 0.9360
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1858 - binary_accuracy: 0.9320
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1859 - binary_accuracy: 0.9307
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1840 - binary_accuracy: 0.9320
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1829 - binary_accuracy: 0.9333
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1823 - binary_accuracy: 0.9347
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1820 - binary_accuracy: 0.9347
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1812 - binary_accuracy: 0.9400
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1797 - binary_accuracy: 0.9373
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1784 - binary_accuracy: 0.9307
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1774 - binary_accuracy: 0.9400
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1772 - binary_accuracy: 0.9333
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1756 - binary_accuracy: 0.9373
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1773 - binary_accuracy: 0.9333
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1769 - binary_accuracy: 0.9373
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1741 - binary_accuracy: 0.9360
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1754 - binary_accuracy: 0.9333
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1736 - binary_accuracy: 0.9333
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1722 - binary_accuracy: 0.9373
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1717 - binary_accuracy: 0.9373
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1718 - binary_accuracy: 0.9347
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1729 - binary_accuracy: 0.9347
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1702 - binary_accuracy: 0.9360
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1693 - binary_accuracy: 0.9347
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1689 - binary_accuracy: 0.9373
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1683 - binary_accuracy: 0.9360
# Epoch 46/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1694 - binary_accuracy: 0.9373
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1683 - binary_accuracy: 0.9373
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1667 - binary_accuracy: 0.9387
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1663 - binary_accuracy: 0.9387
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1662 - binary_accuracy: 0.9373
# 8/8 [==============================] - 0s 997us/step - loss: 0.1501 - binary_accuracy: 0.9520
# Wall time: 6.32 s
# [0.15012726187705994, 0.9520000219345093]

# %%
# create a binary classification model in PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

class TorchBinaryClassifier(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(2, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net = TorchBinaryClassifier()

# %%
# specify loss and optimizer
import torch.optim as optim

criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

X_train_tensor = torch.from_numpy(X_train).float()
Y_train_tensor = torch.from_numpy(Y_train).float().squeeze()

X_test_tensor = torch.from_numpy(X_test).float()
Y_test_tensor = torch.from_numpy(Y_test).float()

trainset = TensorDataset(X_train_tensor, Y_train_tensor)
testset = TensorDataset(X_test_tensor, Y_test_tensor)

train_loader = DataLoader(trainset)
test_loader = DataLoader(testset)

# %%
# %%time
# train the model
net.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader:
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader.dataset)}')
# Out:
# Epoch: 1, training loss: 0.2849081488686788
# Epoch: 2, training loss: 0.20482640950698502
# Epoch: 3, training loss: 0.19693234420092387
# Epoch: 4, training loss: 0.19104204419269807
# Epoch: 5, training loss: 0.1859864163243037
# Epoch: 6, training loss: 0.18130393098743905
# Epoch: 7, training loss: 0.1781190962744343
# Epoch: 8, training loss: 0.17497064127913958
# Epoch: 9, training loss: 0.17219997143104773
# Epoch: 10, training loss: 0.16996008503125812
# Epoch: 11, training loss: 0.16787576446841498
# Epoch: 12, training loss: 0.16618812449474807
# Epoch: 13, training loss: 0.16458432835226774
# Epoch: 14, training loss: 0.16288874179825893
# Epoch: 15, training loss: 0.16150867473513494
# Epoch: 16, training loss: 0.16021032080690087
# Epoch: 17, training loss: 0.15894264029051014
# Epoch: 18, training loss: 0.15757664726312526
# Epoch: 19, training loss: 0.15658849874397196
# Epoch: 20, training loss: 0.15615378342305428
# Epoch: 21, training loss: 0.1548349026934375
# Epoch: 22, training loss: 0.15390898484088064
# Epoch: 23, training loss: 0.1532409487055987
# Epoch: 24, training loss: 0.1523381694769684
# Epoch: 25, training loss: 0.1519162730183856
# Epoch: 26, training loss: 0.15111002301737853
# Epoch: 27, training loss: 0.1516477785450601
# Epoch: 28, training loss: 0.1506310548315573
# Epoch: 29, training loss: 0.1497992392611906
# Epoch: 30, training loss: 0.14930418033218007
# Epoch: 31, training loss: 0.14859105307970252
# Epoch: 32, training loss: 0.14786242688576964
# Epoch: 33, training loss: 0.1474914141320672
# Epoch: 34, training loss: 0.14681396077253855
# Epoch: 35, training loss: 0.14644340962832184
# Epoch: 36, training loss: 0.145231734117567
# Epoch: 37, training loss: 0.1450225609533803
# Epoch: 38, training loss: 0.1445513276147164
# Epoch: 39, training loss: 0.14391775695860223
# Epoch: 40, training loss: 0.14360010171562437
# Epoch: 41, training loss: 0.14291913871181253
# Epoch: 42, training loss: 0.1419962983243541
# Epoch: 43, training loss: 0.14158515684769288
# Epoch: 44, training loss: 0.14125490052749554
# Epoch: 45, training loss: 0.14042122740497523
# Epoch: 46, training loss: 0.14059521465024294
# Epoch: 47, training loss: 0.14004956878374292
# Epoch: 48, training loss: 0.13903704929330896
# Epoch: 49, training loss: 0.13875433009652582
# Epoch: 50, training loss: 0.1377977053878722
# Wall time: 39.3 s

# %%
# evaluate the model
import numpy as np

net.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader:
    output = net(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
print(f'Accuracy: {correct_predictions/len(test_loader.dataset)}')
# Out:
# Accuracy: 0.952

# %% [markdown]
# All models achieved above 90% accuracy. The PyTorch MLP required by far the most lines of code and was the slowest.

# %% [markdown]
# Now I will test the same models on a dataset with 4 features, 3 of which are informative, and one is a random linear combination of the others.

# %%
X_2, Y_2 = make_classification(n_samples = 1000,
                           n_features = 4,
                           n_informative = 3,
                           n_redundant = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2, Y_2, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# display the new classes in terms of the first 3 features using an interactive 3d plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_2_train[:,0], X_2_train[:,1], X_2_train[:,2], c = Y_2_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
