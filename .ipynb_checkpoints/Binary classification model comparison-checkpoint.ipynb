# %% [markdown]
# In this notebook, I will compare several binary classification models using a simulated dataset.

# %% [markdown]
# The data is simulated using scikit-learn's ```make_classification```. First, the models will be trained and tested on a simple dataset with 2 relevant features. Later, they will be trained and tested on a more complex dataset with both redundant and repeated features without any feature engineering. ```make_classification``` documentation can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).

# %% [markdown]
# I will try the following scikit-learn classifiers (click on the model name for documentation): [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html),
# [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html),
# [LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html),
# [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html),
# [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html).

# %% [markdown]
# I will also add multiplayer perceptrons in Keras and PyTorch and evaluate their performances.

# %% [markdown]
# Let's create a dataframe to store accuracies of the classifier for comparison later.

# %%
import pandas as pd

accuracy_df = pd.DataFrame(columns = ['Dataset 1', 'Dataset 2', 'Dataset 3', 'Dataset 4'])

# %%
# create simulated data with 2 features
from sklearn.datasets import make_classification

X, Y = make_classification(n_samples = 1000,
                           n_features = 2,
                           n_informative = 2,
                           n_redundant = 0,
                           n_clusters_per_class = 1,
                           random_state = 47)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 47)

# %%
# plot the training data
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()

# %%
# import the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# fit logistic regression with default parameters
log_reg = LogisticRegression()
log_reg.fit(X_train, Y_train)
# obtain prediction accuracy on test data 
score = log_reg.score(X_test, Y_test)
accuracy_df.loc['Logistic Regression', 'Dataset 1'] = score
print(f'Logistirc Regression: {score}')

# fit the decision tree classifier with default parameters
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, Y_train)
# obtain prediction accuracy on test data
score = dt_clf.score(X_test, Y_test)
accuracy_df.loc['Decision Tree Classifier', 'Dataset 1'] = score
print(f'Decision Tree Classifier: {score}')

# fit linear SVC with default parameters
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
# obtain prediction accuracy on test data
score = linear_svc.score(X_test, Y_test)
accuracy_df.loc['Linear SVC', 'Dataset 1'] = score
print(f'Linear SVC: {score}')

# fit K-neighbors classifier with default parameters
kn_clf = KNeighborsClassifier()
kn_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
score = kn_clf.score(X_test, Y_test)
accuracy_df.loc['KNN Classifier', 'Dataset 1'] = score
print(f'KNN Classifier: {score}')

# fit the random forrest classifier with default parameters
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
score = rf_clf.score(X_test, Y_test)
accuracy_df.loc['Random Forest Classifier', 'Dataset 1'] = score
print(f'Random Forest Classifier: {score}')

# fit the gradient boosting classifier with default parameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
score = gb_clf.score(X_test, Y_test)
accuracy_df.loc['Gradient Boosting Classifier', 'Dataset 1'] = score
print(f'Gradient Boosting Classifier: {score}')
# Out:
# Logistirc Regression: 0.928
# Decision Tree Classifier: 0.944
# Linear SVC: 0.928
# KNN Classifier: 0.952
# Random Forest Classifier: 0.944
# Gradient Boosting Classifier: 0.952

# %%
# %%time
# create a binary classification model in Keras
from keras.models import Sequential
from keras.layers import Dense

# three layer model with 2 feature input and sigmoid output
model = Sequential([
    Dense(30, input_shape=(2,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model.fit(X_train, Y_train, epochs = 50)
# evaluate using the test data
results = model.evaluate(X_test, Y_test)
accuracy_df.loc['Keras NN', 'Dataset 1'] = float(f'{results[1]:.3}')
print(results)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7466 - binary_accuracy: 0.4000
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5702 - binary_accuracy: 0.8227
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4263 - binary_accuracy: 0.9027
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3190 - binary_accuracy: 0.9120
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2527 - binary_accuracy: 0.9307
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2235 - binary_accuracy: 0.9280
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2111 - binary_accuracy: 0.9267
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2062 - binary_accuracy: 0.9267
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2035 - binary_accuracy: 0.9253
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2022 - binary_accuracy: 0.9280
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1993 - binary_accuracy: 0.9267
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1984 - binary_accuracy: 0.9267
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1966 - binary_accuracy: 0.9307
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1958 - binary_accuracy: 0.9293
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1935 - binary_accuracy: 0.9307
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1923 - binary_accuracy: 0.9307
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1914 - binary_accuracy: 0.9307
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1886 - binary_accuracy: 0.9307
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1876 - binary_accuracy: 0.9320
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1866 - binary_accuracy: 0.9320
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1850 - binary_accuracy: 0.9373
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1837 - binary_accuracy: 0.9307
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1826 - binary_accuracy: 0.9320
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1819 - binary_accuracy: 0.9360
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1802 - binary_accuracy: 0.9333
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1802 - binary_accuracy: 0.9307
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1807 - binary_accuracy: 0.9333
# Epoch 28/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1774 - binary_accuracy: 0.9360
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1775 - binary_accuracy: 0.9387
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1767 - binary_accuracy: 0.9360
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1755 - binary_accuracy: 0.9373
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1746 - binary_accuracy: 0.9360
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1744 - binary_accuracy: 0.9373
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1729 - binary_accuracy: 0.9360
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1717 - binary_accuracy: 0.9360
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1713 - binary_accuracy: 0.9387
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1710 - binary_accuracy: 0.9387
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1703 - binary_accuracy: 0.9373
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1709 - binary_accuracy: 0.9400
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1714 - binary_accuracy: 0.9387
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1680 - binary_accuracy: 0.9373
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1676 - binary_accuracy: 0.9400
# Epoch 43/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1671 - binary_accuracy: 0.9387
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1659 - binary_accuracy: 0.9387
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1659 - binary_accuracy: 0.9427
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1655 - binary_accuracy: 0.9373
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1659 - binary_accuracy: 0.9373
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1641 - binary_accuracy: 0.9400
# Epoch 49/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1642 - binary_accuracy: 0.9360
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1643 - binary_accuracy: 0.9400
# 8/8 [==============================] - 0s 997us/step - loss: 0.1499 - binary_accuracy: 0.9520
# [0.14986909925937653, 0.9520000219345093]
# Wall time: 9.08 s

# %%
# create a binary classification model in PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

class TorchBinaryClassifier(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(2, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net = TorchBinaryClassifier()

# %%
# specify loss and optimizer
import torch.optim as optim

criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

X_train_tensor = torch.from_numpy(X_train).float()
Y_train_tensor = torch.from_numpy(Y_train).float().squeeze()

X_test_tensor = torch.from_numpy(X_test).float()
Y_test_tensor = torch.from_numpy(Y_test).float()

trainset = TensorDataset(X_train_tensor, Y_train_tensor)
testset = TensorDataset(X_test_tensor, Y_test_tensor)

train_loader = DataLoader(trainset)
test_loader = DataLoader(testset)

# %%
# %%time
# train the model
net.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader:
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader.dataset)}')
# Out:
# Epoch: 1, training loss: 0.2775266564761017
# Epoch: 2, training loss: 0.200407762183963
# Epoch: 3, training loss: 0.1927069916484955
# Epoch: 4, training loss: 0.1864826624188475
# Epoch: 5, training loss: 0.18060962008905093
# Epoch: 6, training loss: 0.1756346732103169
# Epoch: 7, training loss: 0.17140954885304865
# Epoch: 8, training loss: 0.16794995528579118
# Epoch: 9, training loss: 0.16516834641186384
# Epoch: 10, training loss: 0.1626292976614665
# Epoch: 11, training loss: 0.16007539326554615
# Epoch: 12, training loss: 0.15822895379971547
# Epoch: 13, training loss: 0.15655161588055003
# Epoch: 14, training loss: 0.1551579317367456
# Epoch: 15, training loss: 0.15395721368157805
# Epoch: 16, training loss: 0.15261235765737366
# Epoch: 17, training loss: 0.15151776660844796
# Epoch: 18, training loss: 0.15058531420611204
# Epoch: 19, training loss: 0.14941489024494511
# Epoch: 20, training loss: 0.14828778424109137
# Epoch: 21, training loss: 0.14753371316987612
# Epoch: 22, training loss: 0.14676128047669773
# Epoch: 23, training loss: 0.14609833163543953
# Epoch: 24, training loss: 0.14537728193370275
# Epoch: 25, training loss: 0.14441052908993637
# Epoch: 26, training loss: 0.14414691786712502
# Epoch: 27, training loss: 0.14357937272762258
# Epoch: 28, training loss: 0.14306119306610587
# Epoch: 29, training loss: 0.14231446478401388
# Epoch: 30, training loss: 0.14178135122787597
# Epoch: 31, training loss: 0.14141693618753925
# Epoch: 32, training loss: 0.14203789932699873
# Epoch: 33, training loss: 0.14085161384841194
# Epoch: 34, training loss: 0.14039984313258902
# Epoch: 35, training loss: 0.14005916277766423
# Epoch: 36, training loss: 0.13925566722133467
# Epoch: 37, training loss: 0.13885292227279084
# Epoch: 38, training loss: 0.13854575595078253
# Epoch: 39, training loss: 0.13801204761413585
# Epoch: 40, training loss: 0.13787168158366694
# Epoch: 41, training loss: 0.13784269152383785
# Epoch: 42, training loss: 0.13728498207744755
# Epoch: 43, training loss: 0.1366238641842598
# Epoch: 44, training loss: 0.13659799924200342
# Epoch: 45, training loss: 0.13618257342467646
# Epoch: 46, training loss: 0.13571437393627034
# Epoch: 47, training loss: 0.1362654689397944
# Epoch: 48, training loss: 0.13537595503150562
# Epoch: 49, training loss: 0.1353486326005174
# Epoch: 50, training loss: 0.13505830019155596
# Wall time: 40.2 s

# %%
# evaluate the model
import numpy as np

net.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader:
    output = net(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1

accuracy = correct_predictions/len(test_loader.dataset)
accuracy_df.loc['PyTorch NN', 'Dataset 1'] = accuracy

print(f'Loss: {test_loss/len(test_loader.dataset)}')
print(f'Accuracy: {accuracy}')
# Out:
# Loss: 0.1416768386435433
# Accuracy: 0.96

# %% [markdown]
# Let's look at ```accuracy_df```.

# %%
accuracy_df
# Out:
#                              Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.928       NaN       NaN       NaN
# Decision Tree Classifier         0.944       NaN       NaN       NaN
# Linear SVC                       0.928       NaN       NaN       NaN
# KNN Classifier                   0.952       NaN       NaN       NaN
# Random Forest Classifier         0.944       NaN       NaN       NaN
# Gradient Boosting Classifier     0.952       NaN       NaN       NaN
# Keras NN                         0.952       NaN       NaN       NaN
# PyTorch NN                        0.96       NaN       NaN       NaN

# %% [markdown]
# All models achieved above 90% accuracy. The PyTorch MLP required by far the most lines of code and was the slowest.

# %% [markdown]
# Now I will test the same models on a dataset with 4 features, 3 of which are informative, and one is a random linear combination of the others.

# %%
X_2, Y_2 = make_classification(n_samples = 1000,
                           n_features = 4,
                           n_informative = 3,
                           n_redundant = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2, Y_2, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# display the new classes in terms of the first 3 features using an interactive 3d plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_2_train[:,0], X_2_train[:,1], X_2_train[:,2], c = Y_2_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# fit logistic regression with default parameters
log_reg = LogisticRegression()
log_reg.fit(X_2_train, Y_2_train)
# obtain prediction accuracy on test data 
score = log_reg.score(X_2_test, Y_2_test)
accuracy_df.loc['Logistic Regression', 'Dataset 2'] = score
print(f'Logistirc Regression: {score}')

# fit the decision tree classifier with default parameters
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_2_train, Y_2_train)
# obtain prediction accuracy on test data
score = dt_clf.score(X_2_test, Y_2_test)
accuracy_df.loc['Decision Tree Classifier', 'Dataset 2'] = score
print(f'Decision Tree Classifier: {score}')

# fit linear SVC with default parameters
linear_svc = LinearSVC()
linear_svc.fit(X_2_train, Y_2_train)
# obtain prediction accuracy on test data
score = linear_svc.score(X_2_test, Y_2_test)
accuracy_df.loc['Linear SVC', 'Dataset 2'] = score
print(f'Linear SVC: {score}')

# fit K-neighbors classifier with default parameters
kn_clf = KNeighborsClassifier()
kn_clf.fit(X_2_train, Y_2_train)
# obtain prediction accuracy on the test data
score = kn_clf.score(X_2_test, Y_2_test)
accuracy_df.loc['KNN Classifier', 'Dataset 2'] = score
print(f'KNN Classifier: {score}')

# fit the random forrest classifier with default parameters
rf_clf = RandomForestClassifier()
rf_clf.fit(X_2_train, Y_2_train)
# obtain prediction accuracy on the test data
score = rf_clf.score(X_2_test, Y_2_test)
accuracy_df.loc['Random Forest Classifier', 'Dataset 2'] = score
print(f'Random Forest Classifier: {score}')

# fit the gradient boosting classifier with default parameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_2_train, Y_2_train)
# obtain prediction accuracy on the test data
score = gb_clf.score(X_2_test, Y_2_test)
accuracy_df.loc['Gradient Boosting Classifier', 'Dataset 2'] = score
print(f'Gradient Boosting Classifier: {score}')
# Out:
# Logistirc Regression: 0.928
# Decision Tree Classifier: 0.908
# Linear SVC: 0.928
# KNN Classifier: 0.944
# Random Forest Classifier: 0.94
# Gradient Boosting Classifier: 0.948

# %%
# %%time
# three layer model with 4 feature input and sigmoid output
model_2 = Sequential([
    Dense(30, input_shape=(4,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model_2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model_2.fit(X_2_train, Y_2_train, epochs = 50)
# evaluate using the test data
results = model_2.evaluate(X_2_test, Y_2_test)
accuracy_df.loc['Keras NN', 'Dataset 2'] = float(f'{results[1]:.3}')
print(results)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5978 - binary_accuracy: 0.7747
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4176 - binary_accuracy: 0.9120
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3031 - binary_accuracy: 0.9307
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2420 - binary_accuracy: 0.9320
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2101 - binary_accuracy: 0.9333
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1950 - binary_accuracy: 0.9333
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1879 - binary_accuracy: 0.9307
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1828 - binary_accuracy: 0.9320
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1797 - binary_accuracy: 0.9320
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1777 - binary_accuracy: 0.9347
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1752 - binary_accuracy: 0.9307
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1733 - binary_accuracy: 0.9333
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1719 - binary_accuracy: 0.9347
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1698 - binary_accuracy: 0.9293
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1684 - binary_accuracy: 0.9320
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1672 - binary_accuracy: 0.9333
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1666 - binary_accuracy: 0.9307
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1648 - binary_accuracy: 0.9373
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1637 - binary_accuracy: 0.9333
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1627 - binary_accuracy: 0.9347
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1624 - binary_accuracy: 0.9360
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1616 - binary_accuracy: 0.9373
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1606 - binary_accuracy: 0.9360
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1595 - binary_accuracy: 0.9360
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1587 - binary_accuracy: 0.9347
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1586 - binary_accuracy: 0.9347
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1575 - binary_accuracy: 0.9387
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1569 - binary_accuracy: 0.9387
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1562 - binary_accuracy: 0.9427
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1555 - binary_accuracy: 0.9400
# Epoch 31/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1549 - binary_accuracy: 0.9413
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1538 - binary_accuracy: 0.9373
# Epoch 33/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1537 - binary_accuracy: 0.9400
# Epoch 34/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1530 - binary_accuracy: 0.9413
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1522 - binary_accuracy: 0.9400
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1517 - binary_accuracy: 0.9413
# Epoch 37/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1513 - binary_accuracy: 0.9427
# Epoch 38/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1505 - binary_accuracy: 0.9413
# Epoch 39/50
# 24/24 [==============================] - ETA: 0s - loss: 0.1295 - binary_accuracy: 0.937 - 0s 2ms/step - loss: 0.1496 - binary_accuracy: 0.9427
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1505 - binary_accuracy: 0.9413
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1490 - binary_accuracy: 0.9440
# Epoch 42/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1493 - binary_accuracy: 0.9427
# Epoch 43/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1486 - binary_accuracy: 0.9427
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1473 - binary_accuracy: 0.9440
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1467 - binary_accuracy: 0.9453
# Epoch 46/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1460 - binary_accuracy: 0.9453
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1452 - binary_accuracy: 0.9440
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1456 - binary_accuracy: 0.9440
# Epoch 49/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1451 - binary_accuracy: 0.9440
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1438 - binary_accuracy: 0.9480
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1551 - binary_accuracy: 0.9480
# [0.15512311458587646, 0.9480000138282776]
# Wall time: 3.12 s

# %%
# create another binary classification model in PyTorch
class TorchBinaryClassifier_2(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier_2, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(4, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net_2 = TorchBinaryClassifier_2()

# %%
# specify loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(net_2.parameters())

# %%
# speficy train and test data
X_2_train_tensor = torch.from_numpy(X_2_train).float()
Y_2_train_tensor = torch.from_numpy(Y_2_train).float().squeeze()

X_2_test_tensor = torch.from_numpy(X_2_test).float()
Y_2_test_tensor = torch.from_numpy(Y_2_test).float()

trainset_2 = TensorDataset(X_2_train_tensor, Y_2_train_tensor)
testset_2 = TensorDataset(X_2_test_tensor, Y_2_test_tensor)

train_loader_2 = DataLoader(trainset_2)
test_loader_2 = DataLoader(testset_2)

# %%
# %%time
# train the model
net_2.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader_2:
        optimizer.zero_grad()
        output = net_2(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader_2.dataset)}')
# Out:
# Epoch: 1, training loss: 0.25280356551927
# Epoch: 2, training loss: 0.18578200629396263
# Epoch: 3, training loss: 0.17885887279693216
# Epoch: 4, training loss: 0.17418059277166897
# Epoch: 5, training loss: 0.17076679712293358
# Epoch: 6, training loss: 0.16784234549629182
# Epoch: 7, training loss: 0.16579821028426867
# Epoch: 8, training loss: 0.16405962053770062
# Epoch: 9, training loss: 0.1623262002659025
# Epoch: 10, training loss: 0.16096124342420956
# Epoch: 11, training loss: 0.15938258179654508
# Epoch: 12, training loss: 0.15879198949366188
# Epoch: 13, training loss: 0.15704500806733257
# Epoch: 14, training loss: 0.15521171800737513
# Epoch: 15, training loss: 0.15339787726000959
# Epoch: 16, training loss: 0.1518767463126721
# Epoch: 17, training loss: 0.15051066589147305
# Epoch: 18, training loss: 0.1488578302995222
# Epoch: 19, training loss: 0.1475159162577453
# Epoch: 20, training loss: 0.14613171871149766
# Epoch: 21, training loss: 0.14493553641106546
# Epoch: 22, training loss: 0.14339504214378967
# Epoch: 23, training loss: 0.14205133035794879
# Epoch: 24, training loss: 0.14188391578413823
# Epoch: 25, training loss: 0.14099934548286192
# Epoch: 26, training loss: 0.13888671260814064
# Epoch: 27, training loss: 0.1378660144950899
# Epoch: 28, training loss: 0.13594614230993143
# Epoch: 29, training loss: 0.1360508093681315
# Epoch: 30, training loss: 0.1337955721518153
# Epoch: 31, training loss: 0.1325058437238107
# Epoch: 32, training loss: 0.13147426468077725
# Epoch: 33, training loss: 0.13065390713464534
# Epoch: 34, training loss: 0.12971446745927215
# Epoch: 35, training loss: 0.12862467063422003
# Epoch: 36, training loss: 0.12822584975954232
# Epoch: 37, training loss: 0.1264106062035311
# Epoch: 38, training loss: 0.1254790690637311
# Epoch: 39, training loss: 0.12454444327561942
# Epoch: 40, training loss: 0.12331702526686864
# Epoch: 41, training loss: 0.12292972620159252
# Epoch: 42, training loss: 0.12190729842059465
# Epoch: 43, training loss: 0.12109184132559718
# Epoch: 44, training loss: 0.12009102943130999
# Epoch: 45, training loss: 0.11948558036345676
# Epoch: 46, training loss: 0.11829221609771719
# Epoch: 47, training loss: 0.11784914689453946
# Epoch: 48, training loss: 0.11751014156334745
# Epoch: 49, training loss: 0.11612889746615235
# Epoch: 50, training loss: 0.1153598370034933
# Wall time: 40.3 s

# %%
# evaluate the model
net_2.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader_2:
    output = net_2(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
accuracy = correct_predictions/len(test_loader_2.dataset)
accuracy_df.loc['PyTorch NN', 'Dataset 2'] = float(f'{accuracy:.3}')

print(f'Loss: {test_loss/len(test_loader_2.dataset)}')
print(f'Accuracy: {accuracy}')
# Out:
# Loss: 0.15385138327515557
# Accuracy: 0.948

# %%
accuracy_df
# Out:
#                              Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.928     0.928       NaN       NaN
# Decision Tree Classifier         0.944     0.908       NaN       NaN
# Linear SVC                       0.928     0.928       NaN       NaN
# KNN Classifier                   0.952     0.944       NaN       NaN
# Random Forest Classifier         0.944      0.94       NaN       NaN
# Gradient Boosting Classifier     0.952     0.948       NaN       NaN
# Keras NN                         0.952     0.948       NaN       NaN
# PyTorch NN                        0.96     0.948       NaN       NaN

# %% [markdown]
# All models achieved over 90% accuracy again.

# %% [markdown]
# For the next dataset, I will use 7 features broken down into 4 informative, 2 redundant (linear combinations of informative features), and 1 repeated (randomly chosen from the previous 6).

# %%
X_3, Y_3 = make_classification(n_samples = 1000,
                           n_features = 7,
                           n_informative = 4,
                           n_redundant = 2,
                           n_repeated = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_3_train, X_3_test, Y_3_train, Y_3_test = train_test_split(X_3, Y_3, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# fit logistic regression with default parameters
log_reg = LogisticRegression()
log_reg.fit(X_3_train, Y_3_train)
# obtain prediction accuracy on test data 
score = log_reg.score(X_3_test, Y_3_test)
accuracy_df.loc['Logistic Regression', 'Dataset 3'] = score
print(f'Logistirc Regression: {score}')

# fit the decision tree classifier with default parameters
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_3_train, Y_3_train)
# obtain prediction accuracy on test data
score = dt_clf.score(X_3_test, Y_3_test)
accuracy_df.loc['Decision Tree Classifier', 'Dataset 3'] = score
print(f'Decision Tree Classifier: {score}')

# fit linear SVC with max_iter = 10000 to let the solver converge
linear_svc = LinearSVC(max_iter = 10000)
linear_svc.fit(X_3_train, Y_3_train)
# obtain prediction accuracy on test data
score = linear_svc.score(X_3_test, Y_3_test)
accuracy_df.loc['Linear SVC', 'Dataset 3'] = score
print(f'Linear SVC: {score}')

# fit K-neighbors classifier with default parameters
kn_clf = KNeighborsClassifier()
kn_clf.fit(X_3_train, Y_3_train)
# obtain prediction accuracy on the test data
score = kn_clf.score(X_3_test, Y_3_test)
accuracy_df.loc['KNN Classifier', 'Dataset 3'] = score
print(f'KNN Classifier: {score}')

# fit the random forrest classifier with default parameters
rf_clf = RandomForestClassifier()
rf_clf.fit(X_3_train, Y_3_train)
# obtain prediction accuracy on the test data
score = rf_clf.score(X_3_test, Y_3_test)
accuracy_df.loc['Random Forest Classifier', 'Dataset 3'] = score
print(f'Random Forest Classifier: {score}')

# fit the gradient boosting classifier with default parameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_3_train, Y_3_train)
# obtain prediction accuracy on the test data
score = gb_clf.score(X_3_test, Y_3_test)
accuracy_df.loc['Gradient Boosting Classifier', 'Dataset 3'] = score
print(f'Gradient Boosting Classifier: {score}')
# Out:
# Logistirc Regression: 0.884
# Decision Tree Classifier: 0.856
# Linear SVC: 0.88
# KNN Classifier: 0.9
# Random Forest Classifier: 0.916
# Gradient Boosting Classifier: 0.892

# %%
# %%time
# three layer model with 4 feature input and sigmoid output
model_3 = Sequential([
    Dense(30, input_shape=(7,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model_3.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model_3.fit(X_3_train, Y_3_train, epochs = 50)
# evaluate using the test data
results = model_3.evaluate(X_3_test, Y_3_test)
accuracy_df.loc['Keras NN', 'Dataset 3'] = float(f'{results[1]:.3}')
print(results)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6453 - binary_accuracy: 0.5533
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4744 - binary_accuracy: 0.8627
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3674 - binary_accuracy: 0.9093
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2942 - binary_accuracy: 0.9107
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2480 - binary_accuracy: 0.9107
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2260 - binary_accuracy: 0.9173
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2133 - binary_accuracy: 0.9160
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2061 - binary_accuracy: 0.9213
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2022 - binary_accuracy: 0.9200
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1978 - binary_accuracy: 0.9240
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1950 - binary_accuracy: 0.9267
# Epoch 12/50
# 24/24 [==============================] - 0s 997us/step - loss: 0.1923 - binary_accuracy: 0.9280
# Epoch 13/50
# 24/24 [==============================] - 0s 997us/step - loss: 0.1915 - binary_accuracy: 0.9227
# Epoch 14/50
# 24/24 [==============================] - ETA: 0s - loss: 0.1720 - binary_accuracy: 0.906 - 0s 1ms/step - loss: 0.1884 - binary_accuracy: 0.9293
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1858 - binary_accuracy: 0.9307
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1845 - binary_accuracy: 0.9293
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1831 - binary_accuracy: 0.9280
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1821 - binary_accuracy: 0.9307
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1802 - binary_accuracy: 0.9307
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1793 - binary_accuracy: 0.9320
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1774 - binary_accuracy: 0.9320
# Epoch 22/50
# 24/24 [==============================] - 0s 955us/step - loss: 0.1762 - binary_accuracy: 0.9320
# Epoch 23/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1751 - binary_accuracy: 0.9307
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1747 - binary_accuracy: 0.9333
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1741 - binary_accuracy: 0.9320
# Epoch 26/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1731 - binary_accuracy: 0.9320
# Epoch 27/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1715 - binary_accuracy: 0.9307
# Epoch 28/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1708 - binary_accuracy: 0.9320
# Epoch 29/50
# 24/24 [==============================] - 0s 915us/step - loss: 0.1704 - binary_accuracy: 0.9293
# Epoch 30/50
# 24/24 [==============================] - 0s 997us/step - loss: 0.1703 - binary_accuracy: 0.9347
# Epoch 31/50
# 24/24 [==============================] - 0s 872us/step - loss: 0.1687 - binary_accuracy: 0.9347
# Epoch 32/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1689 - binary_accuracy: 0.9320
# Epoch 33/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1681 - binary_accuracy: 0.9333
# Epoch 34/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1664 - binary_accuracy: 0.9307
# Epoch 35/50
# 24/24 [==============================] - 0s 873us/step - loss: 0.1658 - binary_accuracy: 0.9320
# Epoch 36/50
# 24/24 [==============================] - 0s 873us/step - loss: 0.1667 - binary_accuracy: 0.9267
# Epoch 37/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1671 - binary_accuracy: 0.9333
# Epoch 38/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1655 - binary_accuracy: 0.9240
# Epoch 39/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1639 - binary_accuracy: 0.9307
# Epoch 40/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1640 - binary_accuracy: 0.9320
# Epoch 41/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1628 - binary_accuracy: 0.9307
# Epoch 42/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1641 - binary_accuracy: 0.9307
# Epoch 43/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1625 - binary_accuracy: 0.9307
# Epoch 44/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1618 - binary_accuracy: 0.9307
# Epoch 45/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1629 - binary_accuracy: 0.9333
# Epoch 46/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1603 - binary_accuracy: 0.9307
# Epoch 47/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1618 - binary_accuracy: 0.9293
# Epoch 48/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1603 - binary_accuracy: 0.9293
# Epoch 49/50
# 24/24 [==============================] - 0s 914us/step - loss: 0.1609 - binary_accuracy: 0.9307
# Epoch 50/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.1594 - binary_accuracy: 0.9307
# 8/8 [==============================] - 0s 997us/step - loss: 0.2141 - binary_accuracy: 0.9080
# [0.2141375094652176, 0.9079999923706055]
# Wall time: 2.53 s

# %%
# create another binary classification model in PyTorch
class TorchBinaryClassifier_3(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier_3, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(7, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net_3 = TorchBinaryClassifier_3()

# %%
# specify loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(net_3.parameters())

# %%
# speficy train and test data
X_3_train_tensor = torch.from_numpy(X_3_train).float()
Y_3_train_tensor = torch.from_numpy(Y_3_train).float().squeeze()

X_3_test_tensor = torch.from_numpy(X_3_test).float()
Y_3_test_tensor = torch.from_numpy(Y_3_test).float()

trainset_3 = TensorDataset(X_3_train_tensor, Y_3_train_tensor)
testset_3 = TensorDataset(X_3_test_tensor, Y_3_test_tensor)

train_loader_3 = DataLoader(trainset_3)
test_loader_3 = DataLoader(testset_3)

# %%
# %%time
# train the model
net_3.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader_3:
        optimizer.zero_grad()
        output = net_3(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader_3.dataset)}')
# Out:
# Epoch: 1, training loss: 0.3119406728413887
# Epoch: 2, training loss: 0.224342878774604
# Epoch: 3, training loss: 0.21169046799448551
# Epoch: 4, training loss: 0.20388710304887112
# Epoch: 5, training loss: 0.19903194090842347
# Epoch: 6, training loss: 0.195105564134267
# Epoch: 7, training loss: 0.19157751207935203
# Epoch: 8, training loss: 0.18860448721409376
# Epoch: 9, training loss: 0.1863970737522665
# Epoch: 10, training loss: 0.18397227894363793
# Epoch: 11, training loss: 0.182162193300199
# Epoch: 12, training loss: 0.1796908609056142
# Epoch: 13, training loss: 0.1772569556769263
# Epoch: 14, training loss: 0.17531403904376536
# Epoch: 15, training loss: 0.1734933371526535
# Epoch: 16, training loss: 0.17192654955242911
# Epoch: 17, training loss: 0.17010760917975487
# Epoch: 18, training loss: 0.16904787118331216
# Epoch: 19, training loss: 0.16701726684453153
# Epoch: 20, training loss: 0.16567354226341627
# Epoch: 21, training loss: 0.16475733429186498
# Epoch: 22, training loss: 0.1634548330558182
# Epoch: 23, training loss: 0.16226153294551815
# Epoch: 24, training loss: 0.16120759356574424
# Epoch: 25, training loss: 0.15984716900175333
# Epoch: 26, training loss: 0.15876458014651243
# Epoch: 27, training loss: 0.15717443287824942
# Epoch: 28, training loss: 0.15685610393935578
# Epoch: 29, training loss: 0.15514658375393697
# Epoch: 30, training loss: 0.15482809914105528
# Epoch: 31, training loss: 0.15388191343988591
# Epoch: 32, training loss: 0.15252408457949979
# Epoch: 33, training loss: 0.1526499685638726
# Epoch: 34, training loss: 0.15119589362835686
# Epoch: 35, training loss: 0.15095185433355443
# Epoch: 36, training loss: 0.14966216920986783
# Epoch: 37, training loss: 0.1489979737827954
# Epoch: 38, training loss: 0.1485730202151272
# Epoch: 39, training loss: 0.14736323839236237
# Epoch: 40, training loss: 0.14651282672955387
# Epoch: 41, training loss: 0.14655301423401254
# Epoch: 42, training loss: 0.1448783812510566
# Epoch: 43, training loss: 0.14394886997605638
# Epoch: 44, training loss: 0.14363097045930542
# Epoch: 45, training loss: 0.14260021683377685
# Epoch: 46, training loss: 0.14234970820306383
# Epoch: 47, training loss: 0.1404126076377779
# Epoch: 48, training loss: 0.14010286183519166
# Epoch: 49, training loss: 0.13946446950402108
# Epoch: 50, training loss: 0.1384304758363984
# Wall time: 41.4 s

# %%
# evaluate the model
net_3.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader_3:
    output = net_3(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
accuracy = correct_predictions/len(test_loader_3.dataset)
accuracy_df.loc['PyTorch NN', 'Dataset 3'] = float(f'{accuracy:.3}')

print(f'Loss: {test_loss/len(test_loader_3.dataset)}')
print(f'Accuracy: {accuracy}')
# Out:
# Loss: 0.23988874961413678
# Accuracy: 0.896

# %%
accuracy_df
# Out:
#                              Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.928     0.928     0.884       NaN
# Decision Tree Classifier         0.944     0.908     0.856       NaN
# Linear SVC                       0.928     0.928      0.88       NaN
# KNN Classifier                   0.952     0.944       0.9       NaN
# Random Forest Classifier         0.944      0.94     0.916       NaN
# Gradient Boosting Classifier     0.952     0.948     0.892       NaN
# Keras NN                         0.952     0.948       NaN       NaN
# PyTorch NN                        0.96     0.948       NaN       NaN

# %% [markdown]
# The next dataset will consist of 10 features with the following breakdown: 5 informative, 3 redundant, 2 repeated.

# %%
X_4, Y_4 = make_classification(n_samples = 1000,
                           n_features = 10,
                           n_informative = 5,
                           n_redundant = 3,
                           n_repeated = 2,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_4_train, X_4_test, Y_4_train, Y_4_test = train_test_split(X_4, Y_4, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# fit and evaluate logistic regression
log_reg.fit(X_4_train, Y_4_train)
score = log_reg.score(X_4_test, Y_4_test)
accuracy_df.loc['Logistic Regression', 'Dataset 4'] = score
print(score)
# Out:
# 0.88

# %%
# fit and evaluate the decision tree classifier
dt_clf.fit(X_4_train, Y_4_train)
score = dt_clf.score(X_4_test, Y_4_test)
accuracy_df.loc['Decision Tree Classifier', 'Dataset 4'] = score
print(score)
# Out:
# 0.936

# %%
# fit and evaluate linear SVC
linear_svc.fit(X_4_train, Y_4_train)
linear_svc.score(X_4_test, Y_4_test)
# Out:
# C:\Users\metal\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.88

# %%
# fit and evaluate K-neighbors classifier
kn_clf.fit(X_4_train, Y_4_train)
kn_clf.score(X_4_test, Y_4_test)
# Out:
# 0.956

# %%
# fit and evaluate the random forrest classifier
rf_clf.fit(X_4_train, Y_4_train)
rf_clf.score(X_4_test, Y_4_test)
# Out:
# 0.952

# %%
# fit and evaluate the gradient boosting classifier
gb_clf.fit(X_4_train, Y_4_train)
gb_clf.score(X_4_test, Y_4_test)
# Out:
# 0.952
