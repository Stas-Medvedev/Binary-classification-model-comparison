# %% [markdown]
# In this notebook, I will compare several binary classification models using a simulated dataset.

# %% [markdown]
# The data is simulated using scikit-learn's ```make_classification```. First, the models will be trained and tested on a simple dataset with 2 relevant features. Later, they will be trained and tested on a more complex dataset with both redundant and repeated features without any feature engineering. ```make_classification``` documentation can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).

# %% [markdown]
# I will try the following scikit-learn classifiers (click on the model name for documentation): [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html),
# [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html),
# [LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html),
# [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html),
# [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html).

# %% [markdown]
# I will also add multiplayer perceptrons in Keras and PyTorch and evaluate their performances.

# %%
# create simulated data with 2 features
from sklearn.datasets import make_classification

X, Y = make_classification(n_samples = 1000,
                           n_features = 2,
                           n_informative = 2,
                           n_redundant = 0,
                           n_clusters_per_class = 1,
                           random_state = 47)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 47)

# %%
# plot the training data
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()

# %%
# import the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# fit logistic regression with default parameters
log_reg = LogisticRegression()
log_reg.fit(X_train, Y_train)
# obtain prediction accuracy on test data 
log_reg.score(X_test, Y_test)
# Out:
# 0.928

# %%
# fit the decision tree classifier with default parameters
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, Y_train)
# obtain prediction accuracy on test data
dt_clf.score(X_test, Y_test)
# Out:
# 0.944

# %%
# fit linear SVC with default parameters
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
# obtain prediction accuracy on test data
linear_svc.score(X_test, Y_test)
# Out:
# 0.928

# %%
# fit K-neighbors classifier with default parameters
kn_clf = KNeighborsClassifier()
kn_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
kn_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# fit the random forrest classifier with default parameters
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
rf_clf.score(X_test, Y_test)
# Out:
# 0.94

# %%
# fit the gradient boosting classifier with default parameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, Y_train)
# obtain prediction accuracy on the test data
gb_clf.score(X_test, Y_test)
# Out:
# 0.952

# %%
# %%time
# create a binary classification model in Keras
from keras.models import Sequential
from keras.layers import Dense

# three layer model with 2 feature input and sigmoid output
model = Sequential([
    Dense(30, input_shape=(2,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model.fit(X_train, Y_train, epochs = 50)
# evaluate using the test data
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6594 - binary_accuracy: 0.4893
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5378 - binary_accuracy: 0.7907
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4513 - binary_accuracy: 0.8813
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3775 - binary_accuracy: 0.8973
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3133 - binary_accuracy: 0.9067
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2670 - binary_accuracy: 0.9133
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2369 - binary_accuracy: 0.9200
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2195 - binary_accuracy: 0.9307
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2102 - binary_accuracy: 0.9280
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2047 - binary_accuracy: 0.9267
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2012 - binary_accuracy: 0.9280
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2022 - binary_accuracy: 0.9320
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2005 - binary_accuracy: 0.9307
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1952 - binary_accuracy: 0.9280
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1930 - binary_accuracy: 0.9280
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1927 - binary_accuracy: 0.9307
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1925 - binary_accuracy: 0.9293
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1893 - binary_accuracy: 0.9320
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1886 - binary_accuracy: 0.9320
# Epoch 20/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0703 - binary_accuracy: 1.000 - 0s 1ms/step - loss: 0.1878 - binary_accuracy: 0.9320
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1871 - binary_accuracy: 0.9320
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1866 - binary_accuracy: 0.9320
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1851 - binary_accuracy: 0.9307
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1832 - binary_accuracy: 0.9360
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1825 - binary_accuracy: 0.9360
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1816 - binary_accuracy: 0.9360
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1807 - binary_accuracy: 0.9333
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1801 - binary_accuracy: 0.9360
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1788 - binary_accuracy: 0.9373
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1785 - binary_accuracy: 0.9373
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1782 - binary_accuracy: 0.9320
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1765 - binary_accuracy: 0.9373
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1774 - binary_accuracy: 0.9333
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1749 - binary_accuracy: 0.9373
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1743 - binary_accuracy: 0.9347
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1741 - binary_accuracy: 0.9400
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1746 - binary_accuracy: 0.9333
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1718 - binary_accuracy: 0.9387
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1707 - binary_accuracy: 0.9387
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1706 - binary_accuracy: 0.9333
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1712 - binary_accuracy: 0.9373
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1703 - binary_accuracy: 0.9347
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1674 - binary_accuracy: 0.9373
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1674 - binary_accuracy: 0.9387
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1667 - binary_accuracy: 0.9360
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1666 - binary_accuracy: 0.9373
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1650 - binary_accuracy: 0.9387
# Epoch 48/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1654 - binary_accuracy: 0.9373
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1644 - binary_accuracy: 0.9400
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1640 - binary_accuracy: 0.9400
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1451 - binary_accuracy: 0.9560
# Wall time: 13.3 s
# [0.1451016515493393, 0.9559999704360962]

# %%
# create a binary classification model in PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

class TorchBinaryClassifier(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(2, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net = TorchBinaryClassifier()

# %%
# specify loss and optimizer
import torch.optim as optim

criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

X_train_tensor = torch.from_numpy(X_train).float()
Y_train_tensor = torch.from_numpy(Y_train).float().squeeze()

X_test_tensor = torch.from_numpy(X_test).float()
Y_test_tensor = torch.from_numpy(Y_test).float()

trainset = TensorDataset(X_train_tensor, Y_train_tensor)
testset = TensorDataset(X_test_tensor, Y_test_tensor)

train_loader = DataLoader(trainset)
test_loader = DataLoader(testset)

# %%
# %%time
# train the model
net.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader:
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader.dataset)}')
# Out:
# Epoch: 1, training loss: 0.2806067898691205
# Epoch: 2, training loss: 0.19584858163691146
# Epoch: 3, training loss: 0.1881271620875911
# Epoch: 4, training loss: 0.18370013738216584
# Epoch: 5, training loss: 0.17984610043051724
# Epoch: 6, training loss: 0.17657510236874077
# Epoch: 7, training loss: 0.17341543654613026
# Epoch: 8, training loss: 0.16989918767587006
# Epoch: 9, training loss: 0.16697181327373983
# Epoch: 10, training loss: 0.1645098010330694
# Epoch: 11, training loss: 0.16244089425065067
# Epoch: 12, training loss: 0.16066053988942985
# Epoch: 13, training loss: 0.15939337150053204
# Epoch: 14, training loss: 0.15906651186782256
# Epoch: 15, training loss: 0.15744426892918453
# Epoch: 16, training loss: 0.15593438496488338
# Epoch: 17, training loss: 0.1546679751381574
# Epoch: 18, training loss: 0.1541012507695729
# Epoch: 19, training loss: 0.1528282111947289
# Epoch: 20, training loss: 0.15188400052611542
# Epoch: 21, training loss: 0.15068127286296415
# Epoch: 22, training loss: 0.14885866363480454
# Epoch: 23, training loss: 0.14737358163533887
# Epoch: 24, training loss: 0.1465521511443464
# Epoch: 25, training loss: 0.14521159952995366
# Epoch: 26, training loss: 0.14417209656588967
# Epoch: 27, training loss: 0.14327502348528165
# Epoch: 28, training loss: 0.14251312369847438
# Epoch: 29, training loss: 0.14184796150042286
# Epoch: 30, training loss: 0.14129291032941546
# Epoch: 31, training loss: 0.14037777065010354
# Epoch: 32, training loss: 0.1406985624419273
# Epoch: 33, training loss: 0.13979801142187595
# Epoch: 34, training loss: 0.13930329124935087
# Epoch: 35, training loss: 0.13861985560508522
# Epoch: 36, training loss: 0.13843270188878523
# Epoch: 37, training loss: 0.1379325643168413
# Epoch: 38, training loss: 0.13742014095523336
# Epoch: 39, training loss: 0.13733496819068386
# Epoch: 40, training loss: 0.1367973305259026
# Epoch: 41, training loss: 0.136419021369317
# Epoch: 42, training loss: 0.1369742339533477
# Epoch: 43, training loss: 0.135764838879928
# Epoch: 44, training loss: 0.1354090415212607
# Epoch: 45, training loss: 0.13615730375596952
# Epoch: 46, training loss: 0.13519150940875746
# Epoch: 47, training loss: 0.13469484249885622
# Epoch: 48, training loss: 0.1342138638529844
# Epoch: 49, training loss: 0.13387677878254908
# Epoch: 50, training loss: 0.13451214509911613
# Wall time: 58.9 s

# %%
# evaluate the model
import numpy as np

net.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader:
    output = net(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
print(f'Accuracy: {correct_predictions/len(test_loader.dataset)}')
# Out:
# Accuracy: 0.952

# %% [markdown]
# All models achieved above 90% accuracy. The PyTorch MLP required by far the most lines of code and was the slowest.

# %% [markdown]
# Now I will test the same models on a dataset with 4 features, 3 of which are informative, and one is a random linear combination of the others.

# %%
X_2, Y_2 = make_classification(n_samples = 1000,
                           n_features = 4,
                           n_informative = 3,
                           n_redundant = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2, Y_2, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# display the new classes in terms of the first 3 features using an interactive 3d plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_2_train[:,0], X_2_train[:,1], X_2_train[:,2], c = Y_2_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# fit and evaluate logistic regression
log_reg.fit(X_2_train, Y_2_train)
log_reg.score(X_2_test, Y_2_test)
# Out:
# 0.928

# %%
# fit and evaluate the decision tree classifier
dt_clf.fit(X_2_train, Y_2_train)
dt_clf.score(X_2_test, Y_2_test)
# Out:
# 0.912

# %%
# fit and evaluate linear SVC
linear_svc.fit(X_2_train, Y_2_train)
linear_svc.score(X_2_test, Y_2_test)
# Out:
# 0.928

# %%
# fit and evaluate K-neighbors classifier
kn_clf.fit(X_2_train, Y_2_train)
kn_clf.score(X_2_test, Y_2_test)
# Out:
# 0.944

# %%
# fit and evaluate the random forrest classifier
rf_clf.fit(X_2_train, Y_2_train)
rf_clf.score(X_2_test, Y_2_test)
# Out:
# 0.94

# %%
# fit and evaluate the gradient boosting classifier
gb_clf.fit(X_2_train, Y_2_train)
gb_clf.score(X_2_test, Y_2_test)
# Out:
# 0.948

# %%
# %%time
# three layer model with 4 feature input and sigmoid output
model_2 = Sequential([
    Dense(30, input_shape=(4,), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# compile the model using binary crossentropy as the loss function and
# binary accuracy as the evaluation metric
model_2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model_2.fit(X_2_train, Y_2_train, epochs = 50)
# evaluate using the test data
model_2.evaluate(X_2_test, Y_2_test)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5101 - binary_accuracy: 0.8533
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3487 - binary_accuracy: 0.9160
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2639 - binary_accuracy: 0.9227
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2218 - binary_accuracy: 0.9213
# Epoch 5/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2008 - binary_accuracy: 0.9267
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1908 - binary_accuracy: 0.9320
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1849 - binary_accuracy: 0.9333
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1818 - binary_accuracy: 0.9307
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1789 - binary_accuracy: 0.9307
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1773 - binary_accuracy: 0.9333
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1750 - binary_accuracy: 0.9333
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1733 - binary_accuracy: 0.9293
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1720 - binary_accuracy: 0.9333
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1707 - binary_accuracy: 0.9293
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1685 - binary_accuracy: 0.9333
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1672 - binary_accuracy: 0.9373
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1662 - binary_accuracy: 0.9333
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1645 - binary_accuracy: 0.9320
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1631 - binary_accuracy: 0.9360
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1623 - binary_accuracy: 0.9387
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1613 - binary_accuracy: 0.9347
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1601 - binary_accuracy: 0.9360
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1596 - binary_accuracy: 0.9373
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1580 - binary_accuracy: 0.9413
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1575 - binary_accuracy: 0.9400
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1565 - binary_accuracy: 0.9387
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1593 - binary_accuracy: 0.9413
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1575 - binary_accuracy: 0.9413
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1548 - binary_accuracy: 0.9467
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1543 - binary_accuracy: 0.9400
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1534 - binary_accuracy: 0.9400
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1530 - binary_accuracy: 0.9413
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1530 - binary_accuracy: 0.9427
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1514 - binary_accuracy: 0.9427
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1508 - binary_accuracy: 0.9400
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1500 - binary_accuracy: 0.9427
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1495 - binary_accuracy: 0.9453
# Epoch 38/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1495 - binary_accuracy: 0.9427
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1488 - binary_accuracy: 0.9440
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1489 - binary_accuracy: 0.9413
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1475 - binary_accuracy: 0.9440
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1473 - binary_accuracy: 0.9413
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1459 - binary_accuracy: 0.9453
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1451 - binary_accuracy: 0.9453
# Epoch 45/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1452 - binary_accuracy: 0.9440
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1452 - binary_accuracy: 0.9427
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1443 - binary_accuracy: 0.9480
# Epoch 48/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1436 - binary_accuracy: 0.9453
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1430 - binary_accuracy: 0.9480
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1426 - binary_accuracy: 0.9467
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1551 - binary_accuracy: 0.9480
# Wall time: 3.28 s
# [0.15514613687992096, 0.9480000138282776]

# %%
# create another binary classification model in PyTorch
class TorchBinaryClassifier_2(nn.Module):
    def __init__(self):
        super(TorchBinaryClassifier_2, self).__init__()
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(4, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x
    
net_2 = TorchBinaryClassifier_2()

# %%
# specify loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(net_2.parameters())

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

X_2_train_tensor = torch.from_numpy(X_2_train).float()
Y_2_train_tensor = torch.from_numpy(Y_2_train).float().squeeze()

X_2_test_tensor = torch.from_numpy(X_2_test).float()
Y_2_test_tensor = torch.from_numpy(Y_2_test).float()

trainset_2 = TensorDataset(X_2_train_tensor, Y_2_train_tensor)
testset_2 = TensorDataset(X_2_test_tensor, Y_2_test_tensor)

train_loader_2 = DataLoader(trainset_2)
test_loader_2 = DataLoader(testset_2)

# %%
# %%time
# train the model
net_2.train()

for epoch in range(50):
    # zero the running loss for the epch
    running_loss = 0.0
    
    for data, target in train_loader_2:
        optimizer.zero_grad()
        output = net_2(data)
        loss = criterion(output, target.view(-1,1))
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader_2.dataset)}')
# Out:
# Epoch: 1, training loss: 0.2691517216212874
# Epoch: 2, training loss: 0.18569324299915085
# Epoch: 3, training loss: 0.1780859269709869
# Epoch: 4, training loss: 0.1728730940065346
# Epoch: 5, training loss: 0.16914969950846795
# Epoch: 6, training loss: 0.16549333684746323
# Epoch: 7, training loss: 0.16306409505918548
# Epoch: 8, training loss: 0.16048469466376764
# Epoch: 9, training loss: 0.15825240578111
# Epoch: 10, training loss: 0.15611426540214218
# Epoch: 11, training loss: 0.15411795379722384
# Epoch: 12, training loss: 0.15222461751841332
# Epoch: 13, training loss: 0.15043133919952592
# Epoch: 14, training loss: 0.14886574595658733
# Epoch: 15, training loss: 0.1471568285577319
# Epoch: 16, training loss: 0.1451544934814183
# Epoch: 17, training loss: 0.1436603187113182
# Epoch: 18, training loss: 0.14247890988330938
# Epoch: 19, training loss: 0.1408286253303051
# Epoch: 20, training loss: 0.13954184121245616
# Epoch: 21, training loss: 0.1381687025214714
# Epoch: 22, training loss: 0.137029040790428
# Epoch: 23, training loss: 0.13558542408834884
# Epoch: 24, training loss: 0.13504247945676293
# Epoch: 25, training loss: 0.13369628836120512
# Epoch: 26, training loss: 0.13282099135582476
# Epoch: 27, training loss: 0.13192409845671
# Epoch: 28, training loss: 0.13093867541344487
# Epoch: 29, training loss: 0.1301374030993976
# Epoch: 30, training loss: 0.12907630895627006
# Epoch: 31, training loss: 0.12911635757689627
# Epoch: 32, training loss: 0.1277983081819386
# Epoch: 33, training loss: 0.12734448535721526
# Epoch: 34, training loss: 0.126322564141775
# Epoch: 35, training loss: 0.12577907398444146
# Epoch: 36, training loss: 0.12512443444473223
# Epoch: 37, training loss: 0.12429306516098523
# Epoch: 38, training loss: 0.12386617269230292
# Epoch: 39, training loss: 0.12370112908134108
# Epoch: 40, training loss: 0.12319421236648581
# Epoch: 41, training loss: 0.12225343615809142
# Epoch: 42, training loss: 0.12209913125168913
# Epoch: 43, training loss: 0.12168647324926002
# Epoch: 44, training loss: 0.12085419207560208
# Epoch: 45, training loss: 0.12075032895179895
# Epoch: 46, training loss: 0.11977602632226234
# Epoch: 47, training loss: 0.11973791286037874
# Epoch: 48, training loss: 0.11894626919769258
# Epoch: 49, training loss: 0.1187706787188651
# Epoch: 50, training loss: 0.11758754794643347
# Wall time: 59 s

# %%
# evaluate the model
net_2.eval()

test_loss = 0.0
correct_predictions = 0

for data, target in test_loader_2:
    output = net_2(data)
    loss = criterion(output, target.view(-1,1))
    test_loss += loss.item()
    predicted = np.round(output.detach().numpy().squeeze())
    actual = target.numpy().squeeze()
    if predicted == actual:
        correct_predictions += 1
    
print(f'Loss: {test_loss/len(test_loader_2.dataset)}')
print(f'Accuracy: {correct_predictions/len(test_loader_2.dataset)}')
# Out:
# Loss: 0.15606015600053422
# Accuracy: 0.94

# %% [markdown]
# All models achieved over 90% accuracy again.

# %% [markdown]
# For the next dataset, I will use 7 features broken down into 4 informative, 2 redundant (linear combinations of informative features), and 1 repeated (randomly chosen from the previous 6).

# %%
X_3, Y_3 = make_classification(n_samples = 1000,
                           n_features = 7,
                           n_informative = 4,
                           n_redundant = 2,
                           n_repeated = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_3_train, X_3_test, Y_3_train, Y_3_test = train_test_split(X_3, Y_3, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# fit and evaluate logistic regression
log_reg.fit(X_3_train, Y_3_train)
log_reg.score(X_3_test, Y_3_test)
# Out:
# 0.884

# %%
# fit and evaluate the decision tree classifier
dt_clf.fit(X_3_train, Y_3_train)
dt_clf.score(X_3_test, Y_3_test)
# Out:
# 0.868

# %%
# fit and evaluate linear SVC
linear_svc.fit(X_3_train, Y_3_train)
linear_svc.score(X_3_test, Y_3_test)
# Out:
# C:\Users\metal\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.88

# %%
# fit and evaluate K-neighbors classifier
kn_clf.fit(X_3_train, Y_3_train)
kn_clf.score(X_3_test, Y_3_test)
# Out:
# 0.9

# %%
# fit and evaluate the random forrest classifier
rf_clf.fit(X_3_train, Y_3_train)
rf_clf.score(X_3_test, Y_3_test)
# Out:
# 0.904

# %%
# fit and evaluate the gradient boosting classifier
gb_clf.fit(X_3_train, Y_3_train)
gb_clf.score(X_3_test, Y_3_test)
# Out:
# 0.892
