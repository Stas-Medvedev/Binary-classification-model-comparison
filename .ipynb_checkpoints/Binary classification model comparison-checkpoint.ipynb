# %% [markdown]
# In this notebook, I will compare several binary classification models using a simulated dataset.

# %% [markdown]
# The data is simulated using scikit-learn's ```make_classification```. First, the models will be trained and tested on a simple dataset with 2 relevant features. Later, they will be trained and tested on a more complex dataset with both redundant and repeated features without any feature engineering. ```make_classification``` documentation can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).

# %% [markdown]
# I will try the following scikit-learn classifiers (click on the model name for documentation): [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html),
# [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html),
# [LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html),
# [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html),
# [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html).

# %% [markdown]
# I will also add multiplayer perceptrons in Keras and PyTorch and evaluate their performances.

# %% [markdown]
# Let's create a dataframe to store accuracies of the classifier for comparison later.

# %%
import pandas as pd

accuracy_df = pd.DataFrame(columns = ['Dataset 1', 'Dataset 2', 'Dataset 3', 
                                      'Dataset 4', 'Dataset 5'])

# %%
# create simulated data with 2 features
from sklearn.datasets import make_classification

X, Y = make_classification(n_samples = 1000,
                           n_features = 2,
                           n_informative = 2,
                           n_redundant = 0,
                           n_clusters_per_class = 1,
                           random_state = 47)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 47)

# %%
# plot the training data
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()

# %%
# import the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# initialize scikit-learn classifiers with mostly default values
log_reg = LogisticRegression()
dt_clf = DecisionTreeClassifier()
# initialize Linear SVC with max_iter = 10000 to ensure convergence
linear_svc = LinearSVC(max_iter = 10000)
kn_clf = KNeighborsClassifier()
rf_clf = RandomForestClassifier()
gb_clf = GradientBoostingClassifier()


clf_list = [log_reg, dt_clf, linear_svc, kn_clf, rf_clf, gb_clf]

clf_names = ['Logistic Regression', 'Decision Tree Classifier', 'Linear SVC',
            'KNN Classifier', 'Random Forest Classifier', 'Gradient Boosting Classfier']

# %%
# define a function that will take in training and testing data,
# and then will fit the classifiers and score their predictions

def scikit_clf_fit_score(x_train, y_train, x_test, y_test, dataset_num):
    
    # loop over each classifier in clf_list, fit, score, add score to accuracy_df
    dataset = f'Dataset {dataset_num}'
    
    for i in range(6):
        clf_list[i].fit(x_train, y_train)
        score = clf_list[i].score(x_test, y_test)
        accuracy_df.loc[clf_names[i], dataset] = score
        print(f'{clf_names[i]}: {score}')

# %%
# %%time
scikit_clf_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# Logistic Regression: 0.928
# Decision Tree Classifier: 0.944
# Linear SVC: 0.928
# KNN Classifier: 0.952
# Random Forest Classifier: 0.944
# Gradient Boosting Classfier: 0.952
# Wall time: 459 ms

# %%
# create a function that fits and evaluates a binary classification model in Keras
from keras.models import Sequential
from keras.layers import Dense

def keras_nn_fit_score(x_train, y_train, x_test, y_test, dataset_num, n_epochs = 50):
    
    dataset = f'Dataset {dataset_num}'
    
    # three layer model with ReLU applied to the first two layers
    # and sigmoid to the last one
    model = Sequential([
    Dense(30, input_shape=(x_train.shape[1],), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')])
    
    # compile the model using binary crossentropy as the loss function and
    # binary accuracy as the evaluation metric
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
    model.fit(x_train, y_train, epochs = n_epochs)
    
    # evaluate using the test data
    results = model.evaluate(x_test, y_test)
    accuracy_df.loc['Keras NN', dataset] = float(f'{results[1]:.3}')
    print(results)

# %%
# %%time
keras_nn_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6322 - binary_accuracy: 0.7720
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4915 - binary_accuracy: 0.9080
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3726 - binary_accuracy: 0.9093
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2891 - binary_accuracy: 0.9147
# Epoch 5/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2435 - binary_accuracy: 0.9253
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2217 - binary_accuracy: 0.9307
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2113 - binary_accuracy: 0.9267
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2064 - binary_accuracy: 0.9267
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2038 - binary_accuracy: 0.9267
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2010 - binary_accuracy: 0.9280
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2000 - binary_accuracy: 0.9307
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1980 - binary_accuracy: 0.9307
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1961 - binary_accuracy: 0.9293
# Epoch 14/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1934 - binary_accuracy: 0.9320
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1923 - binary_accuracy: 0.9280
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1925 - binary_accuracy: 0.9360
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1906 - binary_accuracy: 0.9320
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1903 - binary_accuracy: 0.9347
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1903 - binary_accuracy: 0.9320
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1899 - binary_accuracy: 0.9293
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1878 - binary_accuracy: 0.9320
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1847 - binary_accuracy: 0.9307
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1837 - binary_accuracy: 0.9347
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1826 - binary_accuracy: 0.9347
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1807 - binary_accuracy: 0.9347
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1800 - binary_accuracy: 0.9387
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1792 - binary_accuracy: 0.9360
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1779 - binary_accuracy: 0.9333
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1777 - binary_accuracy: 0.9387
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1787 - binary_accuracy: 0.9360
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1768 - binary_accuracy: 0.9387
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1752 - binary_accuracy: 0.9360
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1743 - binary_accuracy: 0.9333
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1750 - binary_accuracy: 0.9387
# Epoch 35/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1734 - binary_accuracy: 0.9373
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1724 - binary_accuracy: 0.9333
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1717 - binary_accuracy: 0.9360
# Epoch 38/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1724 - binary_accuracy: 0.9333
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1716 - binary_accuracy: 0.9320
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1710 - binary_accuracy: 0.9400
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1703 - binary_accuracy: 0.9373
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1688 - binary_accuracy: 0.9413
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1689 - binary_accuracy: 0.9360
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1681 - binary_accuracy: 0.9360
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1678 - binary_accuracy: 0.9360
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1678 - binary_accuracy: 0.9387
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1664 - binary_accuracy: 0.9400
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1689 - binary_accuracy: 0.9360
# Epoch 49/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1662 - binary_accuracy: 0.9387
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1658 - binary_accuracy: 0.9360
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1475 - binary_accuracy: 0.9560
# [0.14747239649295807, 0.9559999704360962]
# Wall time: 4.13 s

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# BCELoss will be used for all neural networks
criterion = nn.BCELoss()

# %%
# create a binary classification model in PyTorch
# the NN will be the same except for the number of input nodes for all datasets

class TorchBinaryClassifier(nn.Module):
    
    def __init__(self, in_dimension):
        
        super(TorchBinaryClassifier, self).__init__()
        
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(in_dimension, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

# set up a function to get dataloaders
def pytorch_loaders(x_train, y_train, x_test, y_test):
    
    X_train_tensor = torch.from_numpy(x_train).float()
    Y_train_tensor = torch.from_numpy(y_train).float().squeeze()

    X_test_tensor = torch.from_numpy(x_test).float()
    Y_test_tensor = torch.from_numpy(y_test).float()

    trainset = TensorDataset(X_train_tensor, Y_train_tensor)
    testset = TensorDataset(X_test_tensor, Y_test_tensor)

    train_loader = DataLoader(trainset)
    test_loader = DataLoader(testset)
    
    return train_loader, test_loader

# %%
# set up a training function
def pytorch_train(model, train_loader, n_epochs = 50):
    
    # define the optimizer
    optimizer = optim.Adam(model.parameters())
    
    # set model to train mode
    model.train()
    print('PyTorch model training...')
    
    for epoch in range(n_epochs):
        # zero the running loss for the epoch
        running_loss = 0.0
        
        for data, target in train_loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target.view(-1,1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            
        print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader.dataset)}')

# %%
import numpy as np

# set up a testing function
def pytorch_test(model, test_loader):
    # set model in evaluation mode
    model.eval()
    print('PyTorch model testing...')
    
    test_loss = 0.0
    correct_predictions = 0
    
    for data, target in test_loader:
        output = model(data)
        loss = criterion(output, target.view(-1,1))
        test_loss += loss.item()
        predicted = np.round(output.detach().numpy().squeeze())
        actual = target.numpy().squeeze()
        
        if predicted == actual:
            correct_predictions += 1
            
    accuracy = correct_predictions/len(test_loader.dataset)
    avg_loss = test_loss/len(test_loader.dataset)
        
    print(f'Loss: {avg_loss}')
    print(f'Accuracy: {accuracy}')
        
    return accuracy

# %%
# define a function that will take in the training and testing data
# and combine the previously defined functions to train and test a pytorch nn

def pytorch_nn_fit_score(x_train, y_train, x_test, y_test, dataset_num, n_epochs = 50):
    
    dataset = f'Dataset {dataset_num}'
    
    # initialize a neural network
    net = TorchBinaryClassifier(x_train.shape[1])
    
    # get data loaders from the training and testing data
    train_loader, test_loader = pytorch_loaders(x_train, y_train, x_test, y_test)
    
    # train the network
    pytorch_train(net, train_loader)
    
    # add a blank line for a clearer print-out
    print('\n')
    # test the network
    accuracy = pytorch_test(net, test_loader)
    accuracy_df.loc['PyTorch NN', dataset] = accuracy

# %%
# %%time
pytorch_nn_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# PyTorch model training...
# Epoch: 1, training loss: 0.31432273716813264
# Epoch: 2, training loss: 0.19436002561619778
# Epoch: 3, training loss: 0.18833506077622103
# Epoch: 4, training loss: 0.18290958013338482
# Epoch: 5, training loss: 0.18032548848806862
# Epoch: 6, training loss: 0.1774901644461497
# Epoch: 7, training loss: 0.17499449759136404
# Epoch: 8, training loss: 0.17295408452704214
# Epoch: 9, training loss: 0.17109273104495637
# Epoch: 10, training loss: 0.1693591836457975
# Epoch: 11, training loss: 0.16790859764985877
# Epoch: 12, training loss: 0.16652129249867934
# Epoch: 13, training loss: 0.16534792145767552
# Epoch: 14, training loss: 0.16392604106663353
# Epoch: 15, training loss: 0.16292523406093673
# Epoch: 16, training loss: 0.16200231532452564
# Epoch: 17, training loss: 0.16094916020809796
# Epoch: 18, training loss: 0.16033673413452243
# Epoch: 19, training loss: 0.15953835536898062
# Epoch: 20, training loss: 0.15860767233055276
# Epoch: 21, training loss: 0.15781612773207612
# Epoch: 22, training loss: 0.15727579240856493
# Epoch: 23, training loss: 0.1567590110899364
# Epoch: 24, training loss: 0.15630042159543214
# Epoch: 25, training loss: 0.15568915974044376
# Epoch: 26, training loss: 0.1557589864666035
# Epoch: 27, training loss: 0.15611640157163448
# Epoch: 28, training loss: 0.15548021147099908
# Epoch: 29, training loss: 0.15458239929803905
# Epoch: 30, training loss: 0.15431755056158059
# Epoch: 31, training loss: 0.15391217124722864
# Epoch: 32, training loss: 0.15348207982864157
# Epoch: 33, training loss: 0.1532014408690352
# Epoch: 34, training loss: 0.15275049643810704
# Epoch: 35, training loss: 0.1524699629367527
# Epoch: 36, training loss: 0.15213512329853227
# Epoch: 37, training loss: 0.1518193081852575
# Epoch: 38, training loss: 0.15167651037448196
# Epoch: 39, training loss: 0.15152969354930337
# Epoch: 40, training loss: 0.15113228723784203
# Epoch: 41, training loss: 0.15093265498789635
# Epoch: 42, training loss: 0.15081507543123765
# Epoch: 43, training loss: 0.15055339463069625
# Epoch: 44, training loss: 0.1501412919688449
# Epoch: 45, training loss: 0.14972303818073093
# Epoch: 46, training loss: 0.1497356085256121
# Epoch: 47, training loss: 0.14971343182835153
# Epoch: 48, training loss: 0.14949717068952245
# Epoch: 49, training loss: 0.14928724328128798
# Epoch: 50, training loss: 0.1491122044618011
#
#
# PyTorch model testing...
# Loss: 0.14868644554845922
# Accuracy: 0.952
# Wall time: 1min 5s

# %% [markdown]
# Let's look at ```accuracy_df```.

# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928       NaN       NaN       NaN       NaN
# Decision Tree Classifier        0.944       NaN       NaN       NaN       NaN
# Linear SVC                      0.928       NaN       NaN       NaN       NaN
# KNN Classifier                  0.952       NaN       NaN       NaN       NaN
# Random Forest Classifier        0.944       NaN       NaN       NaN       NaN
# Gradient Boosting Classfier     0.952       NaN       NaN       NaN       NaN
# Keras NN                        0.956       NaN       NaN       NaN       NaN
# PyTorch NN                      0.952       NaN       NaN       NaN       NaN

# %% [markdown]
# All models achieved above 90% accuracy. The PyTorch MLP required by far the most lines of code and was the slowest.

# %% [markdown]
# Now I will test the same models on a dataset with 4 features, 3 of which are informative, and one is a random linear combination of the others.

# %%
X_2, Y_2 = make_classification(n_samples = 1000,
                           n_features = 4,
                           n_informative = 3,
                           n_redundant = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2, Y_2, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# display the new classes in terms of the first 3 features using an interactive 3d plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_2_train[:,0], X_2_train[:,1], X_2_train[:,2], c = Y_2_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %%time
scikit_clf_fit_score(X_2_train, Y_2_train, X_2_test, Y_2_test, 2)
# Out:
# Logistic Regression: 0.928
# Decision Tree Classifier: 0.912
# Linear SVC: 0.928
# KNN Classifier: 0.944
# Random Forest Classifier: 0.94
# Gradient Boosting Classfier: 0.948
# Wall time: 719 ms

# %%
# %%time
keras_nn_fit_score(X_2_train, Y_2_train, X_2_test, Y_2_test, 2)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5135 - binary_accuracy: 0.8173
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3781 - binary_accuracy: 0.8827
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2958 - binary_accuracy: 0.9027
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2432 - binary_accuracy: 0.9093
# Epoch 5/50
# 24/24 [==============================] - ETA: 0s - loss: 0.2148 - binary_accuracy: 0.875 - 0s 2ms/step - loss: 0.2168 - binary_accuracy: 0.9173
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2009 - binary_accuracy: 0.9253
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1901 - binary_accuracy: 0.9333
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1841 - binary_accuracy: 0.9360
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1800 - binary_accuracy: 0.9373
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1768 - binary_accuracy: 0.9347
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1757 - binary_accuracy: 0.9347
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.
# Epoch: 28, training loss: 0.1306544958901197
# Epoch: 29, training loss: 0.13026669379957764
# Epoch: 30, training loss: 0.12870058812945506
# Epoch: 31, training loss: 0.12808566805907032
# Epoch: 32, training loss: 0.127034121517288
# Epoch: 33, training loss: 0.1265859138650098
# Epoch: 34, training loss: 0.12546782526768635
# Epoch: 35, training loss: 0.12472211888757623
# Epoch: 36, training loss: 0.1245791935422974
# Epoch: 37, training loss: 0.12381077110469686
# Epoch: 38, training loss: 0.12238799246419661
# Epoch: 39, training loss: 0.1221438184845656
# Epoch: 40, training loss: 0.12168477466152133
# Epoch: 41, training loss: 0.1208880328049904
# Epoch: 42, training loss: 0.11978850793213279
# Epoch: 43, training loss: 0.11982069502812953
# Epoch: 44, training loss: 0.11940381142081893
# Epoch: 45, training loss: 0.11907631973858804
# Epoch: 46, training loss: 0.11747093938676358
# Epoch: 47, training loss: 0.11796015762491682
# Epoch: 48, training loss: 0.11740130298650886
# Epoch: 49, training loss: 0.11605168645047062
# Epoch: 50, training loss: 0.11575792746452021
#
#
# PyTorch model testing...
# Loss: 0.1525562431578914
# Accuracy: 0.952
# Wall time: 1min 4s

# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928     0.928       NaN       NaN       NaN
# Decision Tree Classifier        0.944     0.912       NaN       NaN       NaN
# Linear SVC                      0.928     0.928       NaN       NaN       NaN
# KNN Classifier                  0.952     0.944       NaN       NaN       NaN
# Random Forest Classifier        0.944      0.94       NaN       NaN       NaN
# Gradient Boosting Classfier     0.952     0.948       NaN       NaN       NaN
# Keras NN                        0.956     0.944       NaN       NaN       NaN
# PyTorch NN                      0.952     0.952       NaN       NaN       NaN

# %% [markdown]
# All models achieved over 90% accuracy again.

# %% [markdown]
# For the next dataset, I will use 7 features broken down into 4 informative, 2 redundant (linear combinations of informative features), and 1 repeated (randomly chosen from the previous 6).

# %%
X_3, Y_3 = make_classification(n_samples = 1000,
                           n_features = 7,
                           n_informative = 4,
                           n_redundant = 2,
                           n_repeated = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_3_train, X_3_test, Y_3_train, Y_3_test = train_test_split(X_3, Y_3, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# %%time
scikit_clf_fit_score(X_3_train, Y_3_train, X_3_test, Y_3_test, 3)
# Out:
# Logistic Regression: 0.884
# Decision Tree Classifier: 0.852
# Linear SVC: 0.88
# KNN Classifier: 0.9
# Random Forest Classifier: 0.904
# Gradient Boosting Classfier: 0.892
# Wall time: 754 ms

# %%
# %%time
keras_nn_fit_score(X_3_train, Y_3_train, X_3_test, Y_3_test, 3)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5751 - binary_accuracy: 0.7853
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4238 - binary_accuracy: 0.8693
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3228 - binary_accuracy: 0.9053
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2678 - binary_accuracy: 0.9120
# Epoch 5/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2432 - binary_accuracy: 0.9173
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2314 - binary_accuracy: 0.9187
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2245 - binary_accuracy: 0.9160
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2188 - binary_accuracy: 0.9173
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2151 - binary_accuracy: 0.9200
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2111 - binary_accuracy: 0.9227
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2085 - binary_accuracy: 0.9240
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2058 - binary_accuracy: 0.9253
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2046 - binary_accuracy: 0.9227
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2026 - binary_accuracy: 0.9253
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1994 - binary_accuracy: 0.9227
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1973 - binary_accuracy: 0.9280
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1962 - binary_accuracy: 0.9267
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1936 - binary_accuracy: 0.9253
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.
# Epoch: 37, training loss: 0.14910510039608663
# Epoch: 38, training loss: 0.14982045414103937
# Epoch: 39, training loss: 0.1474051719023344
# Epoch: 40, training loss: 0.14727287550851356
# Epoch: 41, training loss: 0.14636120506947184
# Epoch: 42, training loss: 0.14692549477395675
# Epoch: 43, training loss: 0.1443988732551101
# Epoch: 44, training loss: 0.1446484940779359
# Epoch: 45, training loss: 0.1438279876934591
# Epoch: 46, training loss: 0.14421702277913886
# Epoch: 47, training loss: 0.14212540476888919
# Epoch: 48, training loss: 0.14178523210837665
# Epoch: 49, training loss: 0.14136331822512105
# Epoch: 50, training loss: 0.14075504908095715
#
#
# PyTorch model testing...
# Loss: 0.21658331736120062
# Accuracy: 0.908
# Wall time: 1min 6s

# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928     0.928     0.884       NaN       NaN
# Decision Tree Classifier        0.944     0.912     0.852       NaN       NaN
# Linear SVC                      0.928     0.928      0.88       NaN       NaN
# KNN Classifier                  0.952     0.944       0.9       NaN       NaN
# Random Forest Classifier        0.944      0.94     0.904       NaN       NaN
# Gradient Boosting Classfier     0.952     0.948     0.892       NaN       NaN
# Keras NN                        0.956     0.944       0.9       NaN       NaN
# PyTorch NN                      0.952     0.952     0.908       NaN       NaN

# %%
X_4, Y_4 = make_classification(n_samples = 1000,
                           n_features = 10,
                           n_informative = 5,
                           n_redundant = 3,
                           n_repeated = 2,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_4_train, X_4_test, Y_4_train, Y_4_test = train_test_split(X_4, Y_4, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %% [markdown]
# The next dataset will consist of 10 features with the following breakdown: 5 informative, 3 redundant, 2 repeated.

# %%
# %%time
scikit_clf_fit_score(X_4_train, Y_4_train, X_4_test, Y_4_test, 4)
# Out:
# Logistic Regression: 0.88
# Decision Tree Classifier: 0.936
# Linear SVC: 0.88
# KNN Classifier: 0.956
# Random Forest Classifier: 0.952
# Gradient Boosting Classfier: 0.952
# Wall time: 1.05 s

# %%
keras_nn_fit_score(X_4_train, Y_4_train, X_4_test, Y_4_test, 4)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5680 - binary_accuracy: 0.7160
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4001 - binary_accuracy: 0.8933
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3233 - binary_accuracy: 0.8880
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2803 - binary_accuracy: 0.8987
# Epoch 5/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2543 - binary_accuracy: 0.9013
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2336 - binary_accuracy: 0.9093
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2196 - binary_accuracy: 0.9080
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2070 - binary_accuracy: 0.9173
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1952 - binary_accuracy: 0.9227
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1849 - binary_accuracy: 0.9253
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1767 - binary_accuracy: 0.9347
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1682 - binary_accuracy: 0.9347
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1643 - binary_accuracy: 0.9333
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1577 - binary_accuracy: 0.9480
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1527 - binary_accuracy: 0.9387
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1476 - binary_accuracy: 0.9440
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1453 - binary_accuracy: 0.9467
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1426 - binary_accuracy: 0.9480
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1401 - binary_accuracy: 0.9467
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1388 - binary_accuracy: 0.9480
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1368 - binary_accuracy: 0.9427
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1337 - binary_accuracy: 0.9480
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1307 - binary_accuracy: 0.9480
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1295 - binary_accuracy: 0.9467
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1283 - binary_accuracy: 0.9467
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1293 - binary_accuracy: 0.9493
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1257 - binary_accuracy: 0.9467
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1257 - binary_accuracy: 0.9520
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1230 - binary_accuracy: 0.9467
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1219 - binary_accuracy: 0.9480
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1211 - binary_accuracy: 0.9533
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1207 - binary_accuracy: 0.9520
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.
# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928     0.928     0.884      0.88       NaN
# Decision Tree Classifier        0.944     0.912     0.852     0.936       NaN
# Linear SVC                      0.928     0.928      0.88      0.88       NaN
# KNN Classifier                  0.952     0.944       0.9     0.956       NaN
# Random Forest Classifier        0.944      0.94     0.904     0.952       NaN
# Gradient Boosting Classfier     0.952     0.948     0.892     0.952       NaN
# Keras NN                        0.956     0.944       0.9     0.928       NaN
# PyTorch NN                      0.952     0.952     0.908     0.956       NaN

# %%
X_5, Y_5 = make_classification(n_samples = 1000,
                           n_features = 20,
                           n_informative = 7,
                           n_redundant = 7,
                           n_repeated = 6,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_5_train, X_5_test, Y_5_train, Y_5_test = train_test_split(X_5, Y_5, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# %%time
scikit_clf_fit_score(X_5_train, Y_5_train, X_5_test, Y_5_test, 5)
# Out:
# Logistic Regression: 0.96
# Decision Tree Classifier: 0.936
# C:\Users\metal\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Linear SVC: 0.96
# KNN Classifier: 0.972
# Random Forest Classifier: 0.968
# Gradient Boosting Classfier: 0.968
# Wall time: 1.33 s

# %%
keras_nn_fit_score(X_5_train, Y_5_train, X_5_test, Y_5_test, 5)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6296 - binary_accuracy: 0.6933
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2089 - binary_accuracy: 0.9480
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1348 - binary_accuracy: 0.9707
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1048 - binary_accuracy: 0.9760
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0894 - binary_accuracy: 0.9800
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0804 - binary_accuracy: 0.9840
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0731 - binary_accuracy: 0.9853
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0677 - binary_accuracy: 0.9867
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0631 - binary_accuracy: 0.9853
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0601 - binary_accuracy: 0.9867
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0572 - binary_accuracy: 0.9840
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0539 - binary_accuracy: 0.9880
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0521 - binary_accuracy: 0.9880
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0511 - binary_accuracy: 0.9880
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0487 - binary_accuracy: 0.9907
# Epoch 16/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0467 - binary_accuracy: 0.9893
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0461 - binary_accuracy: 0.9893
# Epoch 18/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0443 - binary_accuracy: 0.9907
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0431 - binary_accuracy: 0.9893
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0413 - binary_accuracy: 0.9907
# Epoch 21/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0407 - binary_accuracy: 0.9920
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0387 - binary_accuracy: 0.9933
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0386 - binary_accuracy: 0.9920
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0377 - binary_accuracy: 0.9880
# Epoch 25/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0360 - binary_accuracy: 0.9920
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0352 - binary_accuracy: 0.9907
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0333 - binary_accuracy: 0.9933
# Epoch 28/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0326 - binary_accuracy: 0.9933
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0314 - binary_accuracy: 0.9920
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0305 - binary_accuracy: 0.9933
# Epoch 31/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0311 - binary_accuracy: 0.9920
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0286 - binary_accuracy: 0.9933
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0280 - binary_accuracy: 0.9947
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0268 - binary_accuracy: 0.9947
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0263 - binary_accuracy: 0.9947
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0258 - binary_accuracy: 0.9947
# Epoch 37/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0251 - binary_accuracy: 0.9947
# Epoch 38/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0239 - binary_accuracy: 0.9947
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0237 - binary_accuracy: 0.9947
# Epoch 40/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0185 - binary_accuracy: 1.000 - 0s 1ms/step - loss: 0.0229 - binary_accuracy: 0.9947
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0218 - binary_accuracy: 0.9947
# Epoch 42/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0206 - binary_accuracy: 0.9960
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0203 - binary_accuracy: 0.9947
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0198 - binary_accuracy: 0.9960
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0192 - binary_accuracy: 0.9947
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0192 - binary_accuracy: 0.9933
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0209 - binary_accuracy: 0.9933
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0185 - binary_accuracy: 0.9947
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.