# %% [markdown]
# In this notebook, I will compare several binary classification models using a simulated dataset.

# %% [markdown]
# The data is simulated using scikit-learn's ```make_classification```. First, the models will be trained and tested on a simple dataset with 2 relevant features. Later, they will be trained and tested on a more complex dataset with both redundant and repeated features without any feature engineering. ```make_classification``` documentation can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html).

# %% [markdown]
# I will try the following scikit-learn classifiers (click on the model name for documentation): [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html),
# [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html),
# [LinearSVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html),
# [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html),
# [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html).

# %% [markdown]
# I will also add multiplayer perceptrons in Keras and PyTorch and evaluate their performances.

# %% [markdown]
# Let's create a dataframe to store accuracies of the classifier for comparison later.

# %%
import pandas as pd

accuracy_df = pd.DataFrame(columns = ['Dataset 1', 'Dataset 2', 'Dataset 3', 
                                      'Dataset 4', 'Dataset 5'])

# %%
# create simulated data with 2 features
from sklearn.datasets import make_classification

X, Y = make_classification(n_samples = 1000,
                           n_features = 2,
                           n_informative = 2,
                           n_redundant = 0,
                           n_clusters_per_class = 1,
                           random_state = 47)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 47)

# %%
# plot the training data
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()

# %%
# import the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# initialize scikit-learn classifiers with mostly default values
log_reg = LogisticRegression()
dt_clf = DecisionTreeClassifier()
# initialize Linear SVC with max_iter = 10000 to ensure convergence
linear_svc = LinearSVC(max_iter = 10000)
kn_clf = KNeighborsClassifier()
rf_clf = RandomForestClassifier()
gb_clf = GradientBoostingClassifier()


clf_list = [log_reg, dt_clf, linear_svc, kn_clf, rf_clf, gb_clf]

clf_names = ['Logistic Regression', 'Decision Tree Classifier', 'Linear SVC',
            'KNN Classifier', 'Random Forest Classifier', 'Gradient Boosting Classfier']

# %%
# define a function that will take in training and testing data,
# and then will fit the classifiers and score their predictions

def scikit_clf_fit_score(x_train, y_train, x_test, y_test, dataset_num):
    
    # loop over each classifier in clf_list, fit, score, add score to accuracy_df
    dataset = f'Dataset {dataset_num}'
    
    for i in range(6):
        clf_list[i].fit(x_train, y_train)
        score = clf_list[i].score(x_test, y_test)
        accuracy_df.loc[clf_names[i], dataset] = score
        print(f'{clf_names[i]}: {score}')

# %%
# %%time
scikit_clf_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# Logistic Regression: 0.928
# Decision Tree Classifier: 0.936
# Linear SVC: 0.928
# KNN Classifier: 0.952
# Random Forest Classifier: 0.952
# Gradient Boosting Classfier: 0.952
# Wall time: 730 ms

# %%
# create a function that fits and evaluates a binary classification model in Keras
from keras.models import Sequential
from keras.layers import Dense

def keras_nn_fit_score(x_train, y_train, x_test, y_test, dataset_num, n_epochs = 50):
    
    dataset = f'Dataset {dataset_num}'
    
    # three layer model with ReLU applied to the first two layers
    # and sigmoid to the last one
    model = Sequential([
    Dense(30, input_shape=(x_train.shape[1],), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')])
    
    # compile the model using binary crossentropy as the loss function and
    # binary accuracy as the evaluation metric
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
    model.fit(x_train, y_train, epochs = n_epochs)
    
    # evaluate using the test data
    results = model.evaluate(x_test, y_test)
    accuracy_df.loc['Keras NN', dataset] = float(f'{results[1]:.3}')
    print(results)

# %%
# %%time
keras_nn_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6026 - binary_accuracy: 0.8093
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4749 - binary_accuracy: 0.8680
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3741 - binary_accuracy: 0.8933
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2885 - binary_accuracy: 0.9107
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2381 - binary_accuracy: 0.9227
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2156 - binary_accuracy: 0.9320
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2064 - binary_accuracy: 0.9307
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2024 - binary_accuracy: 0.9293
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1991 - binary_accuracy: 0.9280
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1972 - binary_accuracy: 0.9320
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1960 - binary_accuracy: 0.9320
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1943 - binary_accuracy: 0.9320
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1933 - binary_accuracy: 0.9320
# Epoch 14/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1935 - binary_accuracy: 0.9293
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1900 - binary_accuracy: 0.9333
# Epoch 16/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1891 - binary_accuracy: 0.9307
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1878 - binary_accuracy: 0.9333
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1861 - binary_accuracy: 0.9347
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1853 - binary_accuracy: 0.9320
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1839 - binary_accuracy: 0.9360
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1826 - binary_accuracy: 0.9360
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1817 - binary_accuracy: 0.9333
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1805 - binary_accuracy: 0.9347
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1794 - binary_accuracy: 0.9360
# Epoch 25/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1795 - binary_accuracy: 0.9360
# Epoch 26/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1779 - binary_accuracy: 0.9360
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1765 - binary_accuracy: 0.9347
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1756 - binary_accuracy: 0.9373
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1746 - binary_accuracy: 0.9373
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1743 - binary_accuracy: 0.9360
# Epoch 31/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1725 - binary_accuracy: 0.9360
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1725 - binary_accuracy: 0.9373
# Epoch 33/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1734 - binary_accuracy: 0.9293
# Epoch 34/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0932 - binary_accuracy: 0.968 - 0s 1ms/step - loss: 0.1723 - binary_accuracy: 0.9387
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1697 - binary_accuracy: 0.9387
# Epoch 36/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1693 - binary_accuracy: 0.9360
# Epoch 37/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1689 - binary_accuracy: 0.9400
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1684 - binary_accuracy: 0.9360
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1670 - binary_accuracy: 0.9360
# Epoch 40/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1669 - binary_accuracy: 0.9373
# Epoch 41/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1670 - binary_accuracy: 0.9373
# Epoch 42/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1662 - binary_accuracy: 0.9360
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1655 - binary_accuracy: 0.9373
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1670 - binary_accuracy: 0.9360
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1688 - binary_accuracy: 0.9307
# Epoch 46/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1652 - binary_accuracy: 0.9360
# Epoch 47/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1634 - binary_accuracy: 0.9360
# Epoch 48/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1629 - binary_accuracy: 0.9360
# Epoch 49/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1623 - binary_accuracy: 0.9387
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1627 - binary_accuracy: 0.9400
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1490 - binary_accuracy: 0.9520
# [0.1490274965763092, 0.9520000219345093]
# Wall time: 4.47 s

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# BCELoss will be used for all neural networks
criterion = nn.BCELoss()

# %%
# create a binary classification model in PyTorch
# the NN will be the same except for the number of input nodes for all datasets

class TorchBinaryClassifier(nn.Module):
    
    def __init__(self, in_dimension):
        
        super(TorchBinaryClassifier, self).__init__()
        
        # 3 layer NN similar to the one done in Keras
        self.fc1 = nn.Linear(in_dimension, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 1)
        
        # sigmoid layer for classification
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        
        # apply ReLU after each of the first two layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        # apply sigmoid function before returning the value
        x = self.sig(x)
        
        return x

# %%
# speficy train and test data
from torch.utils.data import TensorDataset, DataLoader

# set up a function to get dataloaders
def pytorch_loaders(x_train, y_train, x_test, y_test):
    
    X_train_tensor = torch.from_numpy(x_train).float()
    Y_train_tensor = torch.from_numpy(y_train).float().squeeze()

    X_test_tensor = torch.from_numpy(x_test).float()
    Y_test_tensor = torch.from_numpy(y_test).float()

    trainset = TensorDataset(X_train_tensor, Y_train_tensor)
    testset = TensorDataset(X_test_tensor, Y_test_tensor)

    train_loader = DataLoader(trainset)
    test_loader = DataLoader(testset)
    
    return train_loader, test_loader

# %%
# set up a training function
def pytorch_train(model, train_loader, n_epochs = 50):
    
    # define the optimizer
    optimizer = optim.Adam(model.parameters())
    
    # set model to train mode
    model.train()
    print('PyTorch model training...')
    
    for epoch in range(n_epochs):
        # zero the running loss for the epoch
        running_loss = 0.0
        
        for data, target in train_loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target.view(-1,1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            
        print(f'Epoch: {epoch + 1}, training loss: {running_loss/len(train_loader.dataset)}')

# %%
import numpy as np

# set up a testing function
def pytorch_test(model, test_loader):
    # set model in evaluation mode
    model.eval()
    print('PyTorch model testing...')
    
    test_loss = 0.0
    correct_predictions = 0
    
    for data, target in test_loader:
        output = model(data)
        loss = criterion(output, target.view(-1,1))
        test_loss += loss.item()
        predicted = np.round(output.detach().numpy().squeeze())
        actual = target.numpy().squeeze()
        
        if predicted == actual:
            correct_predictions += 1
            
    accuracy = correct_predictions/len(test_loader.dataset)
    avg_loss = test_loss/len(test_loader.dataset)
        
    print(f'Loss: {avg_loss}')
    print(f'Accuracy: {accuracy}')
        
    return accuracy

# %%
# define a function that will take in the training and testing data
# and combine the previously defined functions to train and test a pytorch nn

def pytorch_nn_fit_score(x_train, y_train, x_test, y_test, dataset_num, n_epochs = 50):
    
    dataset = f'Dataset {dataset_num}'
    
    # initialize a neural network
    net = TorchBinaryClassifier(x_train.shape[1])
    
    # get data loaders from the training and testing data
    train_loader, test_loader = pytorch_loaders(x_train, y_train, x_test, y_test)
    
    # train the network
    pytorch_train(net, train_loader)
    
    # add a blank line for a clearer print-out
    print('\n')
    # test the network
    accuracy = pytorch_test(net, test_loader)
    accuracy_df.loc['PyTorch NN', dataset] = accuracy

# %%
# %%time
pytorch_nn_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# PyTorch model training...
# Epoch: 1, training loss: 0.29307128964085133
# Epoch: 2, training loss: 0.20700000093184645
# Epoch: 3, training loss: 0.19892314125099803
# Epoch: 4, training loss: 0.19393342000773797
# Epoch: 5, training loss: 0.19065651407731155
# Epoch: 6, training loss: 0.18759458989707248
# Epoch: 7, training loss: 0.1841168263622579
# Epoch: 8, training loss: 0.18063236103030308
# Epoch: 9, training loss: 0.17761153010206665
# Epoch: 10, training loss: 0.17493576333732927
# Epoch: 11, training loss: 0.17266823109764665
# Epoch: 12, training loss: 0.17065717782145656
# Epoch: 13, training loss: 0.16870002588303154
# Epoch: 14, training loss: 0.16688470772982206
# Epoch: 15, training loss: 0.16530406024109653
# Epoch: 16, training loss: 0.16361576385452645
# Epoch: 17, training loss: 0.16236639635863898
# Epoch: 18, training loss: 0.16115859688533085
# Epoch: 19, training loss: 0.1600881971765851
# Epoch: 20, training loss: 0.15926680979310398
# Epoch: 21, training loss: 0.1582944306564453
# Epoch: 22, training loss: 0.15762232323173278
# Epoch: 23, training loss: 0.15695070504641231
# Epoch: 24, training loss: 0.15636389447700155
# Epoch: 25, training loss: 0.15572001852024853
# Epoch: 26, training loss: 0.15530110551583295
# Epoch: 27, training loss: 0.1545873833648919
# Epoch: 28, training loss: 0.15416435033653156
# Epoch: 29, training loss: 0.15349653179659542
# Epoch: 30, training loss: 0.15307281370126202
# Epoch: 31, training loss: 0.15261507742768057
# Epoch: 32, training loss: 0.1523145159544656
# Epoch: 33, training loss: 0.15172446423102867
# Epoch: 34, training loss: 0.15117593770933277
# Epoch: 35, training loss: 0.15092446923129835
# Epoch: 36, training loss: 0.15049100304300647
# Epoch: 37, training loss: 0.15016315721962595
# Epoch: 38, training loss: 0.14976097106663733
# Epoch: 39, training loss: 0.14945775945474649
# Epoch: 40, training loss: 0.1498988309784745
# Epoch: 41, training loss: 0.14928212597125426
# Epoch: 42, training loss: 0.14845468552765456
# Epoch: 43, training loss: 0.14830611383566944
# Epoch: 44, training loss: 0.14787866439232583
# Epoch: 45, training loss: 0.1474688059154032
# Epoch: 46, training loss: 0.1469468060417251
# Epoch: 47, training loss: 0.1468577120836632
# Epoch: 48, training loss: 0.14629960480199466
# Epoch: 49, training loss: 0.14629054659614454
# Epoch: 50, training loss: 0.145815604332166
#
#
# PyTorch model testing...
# Loss: 0.15718353874996183
# Accuracy: 0.952
# Wall time: 1min 14s

# %% [markdown]
# Let's look at ```accuracy_df```.

# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928       NaN       NaN       NaN       NaN
# Decision Tree Classifier        0.936       NaN       NaN       NaN       NaN
# Linear SVC                      0.928       NaN       NaN       NaN       NaN
# KNN Classifier                  0.952       NaN       NaN       NaN       NaN
# Random Forest Classifier        0.952       NaN       NaN       NaN       NaN
# Gradient Boosting Classfier     0.952       NaN       NaN       NaN       NaN
# Keras NN                        0.952       NaN       NaN       NaN       NaN
# PyTorch NN                      0.952       NaN       NaN       NaN       NaN

# %% [markdown]
# All models achieved above 90% accuracy. The PyTorch MLP required by far the most lines of code and was the slowest.

# %% [markdown]
# Now I will test the same models on a dataset with 4 features, 3 of which are informative, and one is a random linear combination of the others.

# %%
X_2, Y_2 = make_classification(n_samples = 1000,
                           n_features = 4,
                           n_informative = 3,
                           n_redundant = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2, Y_2, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# display the new classes in terms of the first 3 features using an interactive 3d plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_2_train[:,0], X_2_train[:,1], X_2_train[:,2], c = Y_2_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %%time
scikit_clf_fit_score(X_2_train, Y_2_train, X_2_test, Y_2_test, 2)
# Out:
# Logistic Regression: 0.928
# Decision Tree Classifier: 0.912
# Linear SVC: 0.928
# KNN Classifier: 0.944
# Random Forest Classifier: 0.944
# Gradient Boosting Classfier: 0.948
# Wall time: 761 ms

# %%
# %%time
keras_nn_fit_score(X_2_train, Y_2_train, X_2_test, Y_2_test, 2)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5487 - binary_accuracy: 0.8507
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3640 - binary_accuracy: 0.9187
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2672 - binary_accuracy: 0.9267
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2213 - binary_accuracy: 0.9293
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2002 - binary_accuracy: 0.9347
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1885 - binary_accuracy: 0.9360
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1826 - binary_accuracy: 0.9347
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1789 - binary_accuracy: 0.9347
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1755 - binary_accuracy: 0.9360
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1743 - binary_accuracy: 0.9347
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1721 - binary_accuracy: 0.9320
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1706 - binary_accuracy: 0.9373
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1696 - binary_accuracy: 0.9333
# Epoch 14/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1678 - binary_accuracy: 0.9373
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1672 - binary_accuracy: 0.9320
# Epoch 16/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1663 - binary_accuracy: 0.9333
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1647 - binary_accuracy: 0.9387
# Epoch 18/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1642 - binary_accuracy: 0.9373
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1631 - binary_accuracy: 0.9360
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.
# Epoch: 32, training loss: 0.13131469684945532
# Epoch: 33, training loss: 0.13085277335514525
# Epoch: 34, training loss: 0.1298381061098922
# Epoch: 35, training loss: 0.12941612147783096
# Epoch: 36, training loss: 0.12853400166567933
# Epoch: 37, training loss: 0.12785985840007236
# Epoch: 38, training loss: 0.12725220456050929
# Epoch: 39, training loss: 0.12685305945977804
# Epoch: 40, training loss: 0.1266549894142039
# Epoch: 41, training loss: 0.1257641954880876
# Epoch: 42, training loss: 0.12528985839789267
# Epoch: 43, training loss: 0.12471684281572398
# Epoch: 44, training loss: 0.12429345520747347
# Epoch: 45, training loss: 0.12434753937116622
# Epoch: 46, training loss: 0.12343938788270695
# Epoch: 47, training loss: 0.12290520620044566
# Epoch: 48, training loss: 0.12307735769473421
# Epoch: 49, training loss: 0.12262200480570169
# Epoch: 50, training loss: 0.1218879431758523
#
#
# PyTorch model testing...
# Loss: 0.13971481464845387
# Accuracy: 0.944
# Wall time: 1min 6s

# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928     0.928       NaN       NaN       NaN
# Decision Tree Classifier        0.936     0.912       NaN       NaN       NaN
# Linear SVC                      0.928     0.928       NaN       NaN       NaN
# KNN Classifier                  0.952     0.944       NaN       NaN       NaN
# Random Forest Classifier        0.952     0.944       NaN       NaN       NaN
# Gradient Boosting Classfier     0.952     0.948       NaN       NaN       NaN
# Keras NN                        0.952     0.952       NaN       NaN       NaN
# PyTorch NN                      0.952     0.944       NaN       NaN       NaN

# %% [markdown]
# All models achieved over 90% accuracy again.

# %% [markdown]
# For the next dataset, I will use 7 features broken down into 4 informative, 2 redundant (linear combinations of informative features), and 1 repeated (randomly chosen from the previous 6).

# %%
X_3, Y_3 = make_classification(n_samples = 1000,
                           n_features = 7,
                           n_informative = 4,
                           n_redundant = 2,
                           n_repeated = 1,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_3_train, X_3_test, Y_3_train, Y_3_test = train_test_split(X_3, Y_3, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# %%time
scikit_clf_fit_score(X_3_train, Y_3_train, X_3_test, Y_3_test, 3)
# Out:
# Logistic Regression: 0.884
# Decision Tree Classifier: 0.852
# Linear SVC: 0.88
# KNN Classifier: 0.9
# Random Forest Classifier: 0.908
# Gradient Boosting Classfier: 0.892
# Wall time: 879 ms

# %%
# %%time
keras_nn_fit_score(X_3_train, Y_3_train, X_3_test, Y_3_test, 3)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6190 - binary_accuracy: 0.6440
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4199 - binary_accuracy: 0.8720
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3115 - binary_accuracy: 0.9093
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2553 - binary_accuracy: 0.9120
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2291 - binary_accuracy: 0.9187
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2148 - binary_accuracy: 0.9160
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2074 - binary_accuracy: 0.9227
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2037 - binary_accuracy: 0.9213
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1989 - binary_accuracy: 0.9227
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1961 - binary_accuracy: 0.9200
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1938 - binary_accuracy: 0.9187
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1919 - binary_accuracy: 0.9213
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1912 - binary_accuracy: 0.9213
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1878 - binary_accuracy: 0.9213
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1863 - binary_accuracy: 0.9240
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1848 - binary_accuracy: 0.9253
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1848 - binary_accuracy: 0.9240
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1828 - binary_accuracy: 0.9240
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1823 - binary_accuracy: 0.9293
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1802 - binary_accuracy: 0.9280
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1791 - binary_accuracy: 0.9267
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1793 - binary_accuracy: 0.9253
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1772 - binary_accuracy: 0.9240
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1774 - binary_accuracy: 0.9240
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1770 - binary_accuracy: 0.9227
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1751 - binary_accuracy: 0.9253
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.
# Epoch: 42, training loss: 0.1458979532086157
# Epoch: 43, training loss: 0.1443556239736824
# Epoch: 44, training loss: 0.1436538186419879
# Epoch: 45, training loss: 0.1420895093526618
# Epoch: 46, training loss: 0.14150414221329286
# Epoch: 47, training loss: 0.13989948087992693
# Epoch: 48, training loss: 0.13983672810434306
# Epoch: 49, training loss: 0.13800858788148426
# Epoch: 50, training loss: 0.13848188309502676
#
#
# PyTorch model testing...
# Loss: 0.23342451128147299
# Accuracy: 0.896
# Wall time: 1min 4s

# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928     0.928     0.884       NaN       NaN
# Decision Tree Classifier        0.936     0.912     0.852       NaN       NaN
# Linear SVC                      0.928     0.928      0.88       NaN       NaN
# KNN Classifier                  0.952     0.944       0.9       NaN       NaN
# Random Forest Classifier        0.952     0.944     0.908       NaN       NaN
# Gradient Boosting Classfier     0.952     0.948     0.892       NaN       NaN
# Keras NN                        0.952     0.952     0.904       NaN       NaN
# PyTorch NN                      0.952     0.944     0.896       NaN       NaN

# %%
X_4, Y_4 = make_classification(n_samples = 1000,
                           n_features = 10,
                           n_informative = 5,
                           n_redundant = 3,
                           n_repeated = 2,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_4_train, X_4_test, Y_4_train, Y_4_test = train_test_split(X_4, Y_4, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %% [markdown]
# The next dataset will consist of 10 features with the following breakdown: 5 informative, 3 redundant, 2 repeated.

# %%
# %%time
scikit_clf_fit_score(X_4_train, Y_4_train, X_4_test, Y_4_test, 4)
# Out:
# Logistic Regression: 0.88
# Decision Tree Classifier: 0.94
# Linear SVC: 0.88
# KNN Classifier: 0.956
# Random Forest Classifier: 0.952
# Gradient Boosting Classfier: 0.952
# Wall time: 1.12 s

# %%
# %%time
keras_nn_fit_score(X_4_train, Y_4_train, X_4_test, Y_4_test, 4)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4784 - binary_accuracy: 0.8133
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3661 - binary_accuracy: 0.8533
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3107 - binary_accuracy: 0.8800
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2772 - binary_accuracy: 0.8907
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2530 - binary_accuracy: 0.9013
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2348 - binary_accuracy: 0.9133
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2186 - binary_accuracy: 0.9200
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2043 - binary_accuracy: 0.9200
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1922 - binary_accuracy: 0.9293
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1821 - binary_accuracy: 0.9267
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1742 - binary_accuracy: 0.9333
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1657 - binary_accuracy: 0.9387
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1589 - binary_accuracy: 0.9413
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1512 - binary_accuracy: 0.9467
# Epoch 15/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1484 - binary_accuracy: 0.9493
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1443 - binary_accuracy: 0.9467
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1391 - binary_accuracy: 0.9547
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1366 - binary_accuracy: 0.9493
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1340 - binary_accuracy: 0.9560
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1307 - binary_accuracy: 0.9507
# Epoch 21/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1293 - binary_accuracy: 0.9547
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1274 - binary_accuracy: 0.9587
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1258 - binary_accuracy: 0.9587
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1245 - binary_accuracy: 0.9533
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1244 - binary_accuracy: 0.9533
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1221 - binary_accuracy: 0.9533
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1204 - binary_accuracy: 0.9573
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1187 - binary_accuracy: 0.9587
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1169 - binary_accuracy: 0.9547
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1162 - binary_accuracy: 0.9600
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1143 - binary_accuracy: 0.9600
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1135 - binary_accuracy: 0.9547
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1131 - binary_accuracy: 0.9613
# Epoch 34/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1123 - binary_accuracy: 0.9600
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1103 - binary_accuracy: 0.9613
# Epoch 36/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1109 - binary_accuracy: 0.9613
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1084 - binary_accuracy: 0.9600
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1077 - binary_accuracy: 0.9627
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1067 - binary_accuracy: 0.9627
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1052 - binary_accuracy: 0.9587
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.


# %%
accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4 Dataset 5
# Logistic Regression             0.928     0.928     0.884      0.88       NaN
# Decision Tree Classifier        0.936     0.912     0.852      0.94       NaN
# Linear SVC                      0.928     0.928      0.88      0.88       NaN
# KNN Classifier                  0.952     0.944       0.9     0.956       NaN
# Random Forest Classifier        0.952     0.944     0.908     0.952       NaN
# Gradient Boosting Classfier     0.952     0.948     0.892     0.952       NaN
# Keras NN                        0.952     0.952     0.904     0.928       NaN
# PyTorch NN                      0.952     0.944     0.896     0.948       NaN

# %%
X_5, Y_5 = make_classification(n_samples = 1000,
                           n_features = 20,
                           n_informative = 7,
                           n_redundant = 7,
                           n_repeated = 6,
                           n_clusters_per_class = 1,
                           random_state = 47)

X_5_train, X_5_test, Y_5_train, Y_5_test = train_test_split(X_5, Y_5, 
                                                            test_size = 0.25,
                                                            random_state = 47)

# %%
# %%time
scikit_clf_fit_score(X_5_train, Y_5_train, X_5_test, Y_5_test, 5)
# Out:
# Logistic Regression: 0.96
# Decision Tree Classifier: 0.916
# C:\Users\metal\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Linear SVC: 0.96
# KNN Classifier: 0.972
# Random Forest Classifier: 0.964
# Gradient Boosting Classfier: 0.968
# Wall time: 1.59 s

# %%
# %%time
keras_nn_fit_score(X_5_train, Y_5_train, X_5_test, Y_5_test, 5)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9674 - binary_accuracy: 0.4613
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5114 - binary_accuracy: 0.8080
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3279 - binary_accuracy: 0.9133
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2222 - binary_accuracy: 0.9400
# Epoch 5/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1577 - binary_accuracy: 0.9573
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1195 - binary_accuracy: 0.9720
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0989 - binary_accuracy: 0.9747
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0847 - binary_accuracy: 0.9773
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0753 - binary_accuracy: 0.9800
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0680 - binary_accuracy: 0.9853
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0630 - binary_accuracy: 0.9853
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0585 - binary_accuracy: 0.9867
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0555 - binary_accuracy: 0.9880
# Epoch 14/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0520 - binary_accuracy: 0.9867
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0502 - binary_accuracy: 0.9907
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0485 - binary_accuracy: 0.9893
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0457 - binary_accuracy: 0.9893
# Epoch 18/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0426 - binary_accuracy: 0.9933
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0434 - binary_accuracy: 0.9920
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0403 - binary_accuracy: 0.9920
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0395 - binary_accuracy: 0.9933
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0390 - binary_accuracy: 0.9893
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0373 - binary_accuracy: 0.9933
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0363 - binary_accuracy: 0.9933
# Epoch 25/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0355 - binary_accuracy: 0.9920
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0341 - binary_accuracy: 0.9933
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0328 - binary_accuracy: 0.9933
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0316 - binary_accuracy: 0.9947
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0311 - binary_accuracy: 0.9947
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0302 - binary_accuracy: 0.9947
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0293 - binary_accuracy: 0.9933
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0286 - binary_accuracy: 0.9947
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0275 - binary_accuracy: 0.9960
# Epoch 34/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0267 - binary_accuracy: 0.9947
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0258 - binary_accuracy: 0.9947
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0254 - binary_accuracy: 0.9960
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0253 - binary_accuracy: 0.9947
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0237 - binary_accuracy: 0.9947
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0233 - binary_accuracy: 0.9947
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0225 - binary_accuracy: 0.9960
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0222 - binary_accuracy: 0.9947
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0213 - binary_accuracy: 0.9960
# Epoch 43/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0212 - binary_accuracy: 0.9947
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0206 - binary_accuracy: 0.9960
# Epoch 45/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0200 - binary_accuracy: 0.9947
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0192 - binary_accuracy: 0.9960
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0190 - binary_accuracy: 0.9960
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0187 - binary_accuracy: 0.9947
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0177 - binary_accuracy: 0.9960
# Epoch 50/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0181 - binary_accuracy: 0.9960
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1218 - binary_accuracy: 0.9720
# [0.1217561736702919, 0.972000002861023]
# Wall time: 3.52 s

# %%
# %%time
pytorch_nn_fit_score(X_5_train, Y_5_train, X_5_test, Y_5_test, 5)
# Out:
# PyTorch model training...
# Epoch: 1, training loss: 0


# %%
X_train, X_test, Y_train, Y_test = train_test_split(moon_X, moon_Y, 
                                                    test_size = 0.25, random_state = 47)

# %%
plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# modify the functions to use the new DataFrame

def moon_scikit_clf_fit_score(x_train, y_train, x_test, y_test, dataset_num):
    
    # loop over each classifier in clf_list, fit, score, add score to accuracy_df
    dataset = f'Dataset {dataset_num}'
    
    for i in range(6):
        clf_list[i].fit(x_train, y_train)
        score = clf_list[i].score(x_test, y_test)
        moon_accuracy_df.loc[clf_names[i], dataset] = score
        print(f'{clf_names[i]}: {score}')

# %%
def moon_keras_nn_fit_score(x_train, y_train, x_test, y_test, dataset_num, n_epochs = 50):
    
    dataset = f'Dataset {dataset_num}'
    
    # three layer model with ReLU applied to the first two layers
    # and sigmoid to the last one
    model = Sequential([
    Dense(30, input_shape=(x_train.shape[1],), activation = 'relu'),
    Dense(30, activation = 'relu'),
    Dense(1, activation = 'sigmoid')])
    
    # compile the model using binary crossentropy as the loss function and
    # binary accuracy as the evaluation metric
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
    model.fit(x_train, y_train, epochs = n_epochs)
    
    # evaluate using the test data
    results = model.evaluate(x_test, y_test)
    moon_accuracy_df.loc['Keras NN', dataset] = float(f'{results[1]:.3}')
    print(results)

# %%
def moon_pytorch_nn_fit_score(x_train, y_train, x_test, y_test, dataset_num, n_epochs = 50):
    
    dataset = f'Dataset {dataset_num}'
    
    # initialize a neural network
    net = TorchBinaryClassifier(x_train.shape[1])
    
    # get data loaders from the training and testing data
    train_loader, test_loader = pytorch_loaders(x_train, y_train, x_test, y_test)
    
    # train the network
    pytorch_train(net, train_loader)
    
    # add a blank line for a clearer print-out
    print('\n')
    # test the network
    accuracy = pytorch_test(net, test_loader)
    moon_accuracy_df.loc['PyTorch NN', dataset] = accuracy

# %%
# %%time
moon_scikit_clf_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# Logistic Regression: 0.88
# Decision Tree Classifier: 0.992
# Linear SVC: 0.88
# KNN Classifier: 0.996
# Random Forest Classifier: 0.988
# Gradient Boosting Classfier: 0.992
# Wall time: 630 ms

# %%
# %%time
moon_keras_nn_fit_score(X_train, Y_train, X_test, Y_test, 1)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6279 - binary_accuracy: 0.6333
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5307 - binary_accuracy: 0.7973
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4558 - binary_accuracy: 0.8187
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3937 - binary_accuracy: 0.8387
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3432 - binary_accuracy: 0.8707
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3065 - binary_accuracy: 0.8773
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2820 - binary_accuracy: 0.8827
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2674 - binary_accuracy: 0.8867
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2586 - binary_accuracy: 0.8880
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2511 - binary_accuracy: 0.8880
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2439 - binary_accuracy: 0.8867
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2386 - binary_accuracy: 0.8853
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2319 - binary_accuracy: 0.8920
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2255 - binary_accuracy: 0.8960
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2182 - binary_accuracy: 0.9000
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2100 - binary_accuracy: 0.9067
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2001 - binary_accuracy: 0.9040
# Epoch 18/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1889 - binary_accuracy: 0.9187
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1780 - binary_accuracy: 0.9293
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1668 - binary_accuracy: 0.9333
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1558 - binary_accuracy: 0.9373
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1467 - binary_accuracy: 0.9427
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1375 - binary_accuracy: 0.9413
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1277 - binary_accuracy: 0.9547
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1181 - binary_accuracy: 0.9587
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1096 - binary_accuracy: 0.9600
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1027 - binary_accuracy: 0.9627
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0942 - binary_accuracy: 0.9627
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0879 - binary_accuracy: 0.9693
# Epoch 30/50
# 24/24 [==============================] - 0s 956us/step - loss: 0.0821 - binary_accuracy: 0.9733
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.
# Epoch: 42, training loss: 0.0024644913340186084
# Epoch: 43, training loss: 0.0014082752152336487
# Epoch: 44, training loss: 0.000985984721866013
# Epoch: 45, training loss: 0.0011274905895340907
# Epoch: 46, training loss: 0.0002499368870577617
# Epoch: 47, training loss: 0.00012026510053234081
# Epoch: 48, training loss: 0.00028409494397393096
# Epoch: 49, training loss: 0.003914741781043858
# Epoch: 50, training loss: 0.0008359812117724156
#
#
# PyTorch model testing...
# Loss: 0.0018560123274041303
# Accuracy: 1.0
# Wall time: 1min 5s

# %%
moon_accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.88       NaN       NaN       NaN
# Decision Tree Classifier        0.992       NaN       NaN       NaN
# Linear SVC                       0.88       NaN       NaN       NaN
# KNN Classifier                  0.996       NaN       NaN       NaN
# Random Forest Classifier        0.988       NaN       NaN       NaN
# Gradient Boosting Classfier     0.992       NaN       NaN       NaN
# Keras NN                        0.992       NaN       NaN       NaN
# PyTorch NN                          1       NaN       NaN       NaN

# %%
moon_X_2, moon_Y_2 = make_moons(1000, noise = 0.3, random_state=47)
X_train, X_test, Y_train, Y_test = train_test_split(moon_X_2, moon_Y_2, 
                                                    test_size = 0.25, random_state = 47)

# %%
plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %%time
moon_scikit_clf_fit_score(X_train, Y_train, X_test, Y_test, 2)
# Out:
# Logistic Regression: 0.884
# Decision Tree Classifier: 0.864
# Linear SVC: 0.884
# KNN Classifier: 0.888
# Random Forest Classifier: 0.9
# Gradient Boosting Classfier: 0.896
# Wall time: 618 ms

# %%
# %%time
moon_keras_nn_fit_score(X_train, Y_train, X_test, Y_test, 2)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6559 - binary_accuracy: 0.6387
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5450 - binary_accuracy: 0.8120
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4703 - binary_accuracy: 0.8173
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4180 - binary_accuracy: 0.8213
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3819 - binary_accuracy: 0.8307
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3589 - binary_accuracy: 0.8360
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3436 - binary_accuracy: 0.8413
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3316 - binary_accuracy: 0.8427
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3220 - binary_accuracy: 0.8507
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3168 - binary_accuracy: 0.8520
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3128 - binary_accuracy: 0.8533
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3098 - binary_accuracy: 0.8520
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3100 - binary_accuracy: 0.8560
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3042 - binary_accuracy: 0.8560
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3020 - binary_accuracy: 0.8560
# Epoch 16/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3013 - binary_accuracy: 0.8547
# Epoch 17/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2974 - binary_accuracy: 0.8573
# Epoch 18/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2944 - binary_accuracy: 0.8560
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2915 - binary_accuracy: 0.8560
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2895 - binary_accuracy: 0.8573
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2859 - binary_accuracy: 0.8600
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2830 - binary_accuracy: 0.8627
# Epoch 23/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2799 - binary_accuracy: 0.8667
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2769 - binary_accuracy: 0.8707
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2749 - binary_accuracy: 0.8667
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2726 - binary_accuracy: 0.8760
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2677 - binary_accuracy: 0.8773
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2642 - binary_accuracy: 0.8800
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2610 - binary_accuracy: 0.8800
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2581 - binary_accuracy: 0.8853
# Epoch 31/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2543 - binary_accuracy: 0.8880
# Epoch 32/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2521 - binary_accuracy: 0.8867
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2486 - binary_accuracy: 0.8893
# Epoch 34/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2463 - binary_accuracy: 0.8920
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2446 - binary_accuracy: 0.8960
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2431 - binary_accuracy: 0.8933
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2409 - binary_accuracy: 0.8987
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2396 - binary_accuracy: 0.9027
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2382 - binary_accuracy: 0.8960
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2347 - binary_accuracy: 0.9000
# Epoch 41/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.
uracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.88     0.884       NaN       NaN
# Decision Tree Classifier        0.992     0.864       NaN       NaN
# Linear SVC                       0.88     0.884       NaN       NaN
# KNN Classifier                  0.996     0.888       NaN       NaN
# Random Forest Classifier        0.988       0.9       NaN       NaN
# Gradient Boosting Classfier     0.992     0.896       NaN       NaN
# Keras NN                        0.992     0.892       NaN       NaN
# PyTorch NN                          1     0.888       NaN       NaN

# %%
moon_X_3, moon_Y_3 = make_moons(1000, noise = 0.5, random_state=47)
X_train, X_test, Y_train, Y_test = train_test_split(moon_X_3, moon_Y_3, 
                                                    test_size = 0.25, random_state = 47)

# %%
plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %%time
moon_scikit_clf_fit_score(X_train, Y_train, X_test, Y_test, 3)
# Out:
# Logistic Regression: 0.852
# Decision Tree Classifier: 0.764
# Linear SVC: 0.856
# KNN Classifier: 0.828
# Random Forest Classifier: 0.804
# Gradient Boosting Classfier: 0.816
# Wall time: 666 ms

# %%
# %%time
moon_keras_nn_fit_score(X_train, Y_train, X_test, Y_test, 3)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6203 - binary_accuracy: 0.7707
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5405 - binary_accuracy: 0.7840
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4775 - binary_accuracy: 0.7920
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4413 - binary_accuracy: 0.7973
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4250 - binary_accuracy: 0.8000
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4193 - binary_accuracy: 0.7973
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4184 - binary_accuracy: 0.7973
# Epoch 8/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4176 - binary_accuracy: 0.7973
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4151 - binary_accuracy: 0.8013
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4139 - binary_accuracy: 0.8000
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4126 - binary_accuracy: 0.8013
# Epoch 12/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4130 - binary_accuracy: 0.8027
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4120 - binary_accuracy: 0.8027
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4108 - binary_accuracy: 0.8027
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4104 - binary_accuracy: 0.8013
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4106 - binary_accuracy: 0.8000
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4094 - binary_accuracy: 0.8027
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4080 - binary_accuracy: 0.8027
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4076 - binary_accuracy: 0.8000
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4077 - binary_accuracy: 0.8013
# Epoch 21/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4068 - binary_accuracy: 0.8000
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4052 - binary_accuracy: 0.8027
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4052 - binary_accuracy: 0.8000
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4040 - binary_accuracy: 0.8013
# Epoch 25/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4038 - binary_accuracy: 0.8000
# Epoch 26/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4030 - binary_accuracy: 0.7973
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4031 - binary_accuracy: 0.8000
# Epoch 28/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4024 - binary_accuracy: 0.7987
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4021 - binary_accuracy: 0.7960
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4013 - binary_accuracy: 0.8000
# Epoch 31/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4006 - binary_accuracy: 0.7987
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3998 - binary_accuracy: 0.7960
# Epoch 33/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3996 - binary_accuracy: 0.7973
# Epoch 34/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3993 - binary_accuracy: 0.8000
# Epoch 35/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3985 - binary_accuracy: 0.7973
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3984 - binary_accuracy: 0.7960
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3973 - binary_accuracy: 0.7973
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3973 - binary_accuracy: 0.7987
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3966 - binary_accuracy: 0.7933
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3969 - binary_accuracy: 0.7960
# Epoch 41/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3955 - binary_accuracy: 0.7960
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3950 - binary_accuracy: 0.7947
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3944 - binary_accuracy: 0.7987
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3943 - binary_accuracy: 0.7987
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3936 - binary_accuracy: 0.7973
# Epoch 46/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3926 - binary_accuracy: 0.8000
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3927 - binary_accuracy: 0.8000
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3918 - binary_accuracy: 0.7973
# Epoch 49/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3915 - binary_accuracy: 0.7973
# Epoch 50/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3923 - binary_accuracy: 0.7960
# 1/8 [==>...........................] - ETA: 0s - loss: 0.5900 - binary_accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0069s). Check your callbacks.
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3806 - binary_accuracy: 0.8480
# [0.3806024193763733, 0.8479999899864197]
# Wall time: 3.55 s

# %%
# %%time
moon_pytorch_nn_fit_score(X_train, Y_train, X_test, Y_test, 3)
# Out:
# PyTorch model training...
# Epoch: 1, training loss: 0.4841602905311932
# Epoch: 2, training loss: 0.4205174078391865
# Epoch: 3, training loss: 0.4156870466914649
# Epoch: 4, training loss: 0.41212062812340444
# Epoch: 5, training loss: 0.40918804331403225
# Epoch: 6, training loss: 0.40674966389577216
# Epoch: 7, training loss: 0.4049426787815367
# Epoch: 8, training loss: 0.4032244142617177
# Epoch: 9, training loss: 0.40163996208738534
# Epoch: 10, training loss: 0.39954623387428
# Epoch: 11, training loss: 0.3983780385894546
# Epoch: 12, training loss: 0.39765459586718743
# Epoch: 13, training loss: 0.39682096432034936
# Epoch: 14, training loss: 0.3960539574076732
# Epoch: 15, training loss: 0.39539340494726394
# Epoch: 16, training loss: 0.3947545323984232
# Epoch: 17, training loss: 0.3940169144125539
# Epoch: 18, training loss: 0.39358186075706425
# Epoch: 19, training loss: 0.39294046635665775
# Epoch: 20, training loss: 0.39239596461103066
# Epoch: 21, training loss: 0.39210620266292245
# Epoch: 22, training loss: 0.39160159035523734
# Epoch: 23, training loss: 0.39114002441075474
# Epoch: 24, training loss: 0.39105781614171187
# Epoch: 25, training loss: 0.39054262980502485
# Epoch: 26, training loss: 0.3903588178624729
# Epoch: 27, training loss: 0.38991334505703223
# Epoch: 28, training loss: 0.38961930564794844
# Epoch: 29, training loss: 0.3890983403807525
# Epoch: 30, training loss: 0.3892193666217402
# Epoch: 31, training loss: 0.3887261291239605
# Epoch: 32, training loss: 0.38828082470120473
# Epoch: 33, training loss: 0.3879269989453023
# Epoch: 34, training loss: 0.38786692366343534
# Epoch: 35, training loss: 0.3877234620897798
# Epoch: 36, training loss: 0.387377956583446
# Epoch: 37, training loss: 0.3871789983496613
# Epoch: 38, training loss: 0.38680503125155036
# Epoch: 39, training loss: 0.38680888812807585
# Epoch: 40, training loss: 0.38641578942296717
# Epoch: 41, training loss: 0.3863603492248027
# Epoch: 42, training loss: 0.3861524057464267
# Epoch: 43, training loss: 0.38591965109917997
# Epoch: 44, training loss: 0.3859385168655135
# Epoch: 45, training loss: 0.3856234988165379
# Epoch: 46, training loss: 0.38549304852081695
# Epoch: 47, training loss: 0.38528726317566664
# Epoch: 48, training loss: 0.38508828890445873
# Epoch: 49, training loss: 0.3853769677163315
# Epoch: 50, training loss: 0.38480903129812216
#
#
# PyTorch model testing...
# Loss: 0.38715263280970974
# Accuracy: 0.82
# Wall time: 1min 4s

# %%
moon_accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.88     0.884     0.852       NaN
# Decision Tree Classifier        0.992     0.864     0.764       NaN
# Linear SVC                       0.88     0.884     0.856       NaN
# KNN Classifier                  0.996     0.888     0.828       NaN
# Random Forest Classifier        0.988       0.9     0.804       NaN
# Gradient Boosting Classfier     0.992     0.896     0.816       NaN
# Keras NN                        0.992     0.892     0.848       NaN
# PyTorch NN                          1     0.888      0.82       NaN

# %%
moon_X_4, moon_Y_4 = make_moons(1000, noise = 0.7, random_state=47)
X_train, X_test, Y_train, Y_test = train_test_split(moon_X_4, moon_Y_4, 
                                                    test_size = 0.25, random_state = 47)

# %%
plt.figure(figsize=(8,5))
plt.scatter(X_train[:,0], X_train[:,1], c = Y_train)
plt.title('Training Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.7333333333333">

# %%
# %%time
moon_scikit_clf_fit_score(X_train, Y_train, X_test, Y_test, 4)
# Out:
# Logistic Regression: 0.828
# Decision Tree Classifier: 0.708
# Linear SVC: 0.824
# KNN Classifier: 0.756
# Random Forest Classifier: 0.728
# Gradient Boosting Classfier: 0.796
# Wall time: 650 ms

# %%
# %%time
moon_keras_nn_fit_score(X_train, Y_train, X_test, Y_test, 4)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6391 - binary_accuracy: 0.6533
# Epoch 2/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5624 - binary_accuracy: 0.7467
# Epoch 3/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5137 - binary_accuracy: 0.7640
# Epoch 4/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4897 - binary_accuracy: 0.7653
# Epoch 5/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4827 - binary_accuracy: 0.7640
# Epoch 6/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4807 - binary_accuracy: 0.7627
# Epoch 7/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4802 - binary_accuracy: 0.7613
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4782 - binary_accuracy: 0.7613
# Epoch 9/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4788 - binary_accuracy: 0.7627
# Epoch 10/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4773 - binary_accuracy: 0.7627
# Epoch 11/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4771 - binary_accuracy: 0.7600
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4780 - binary_accuracy: 0.7600
# Epoch 13/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4759 - binary_accuracy: 0.7627
# Epoch 14/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4759 - binary_accuracy: 0.7627
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4752 - binary_accuracy: 0.7627
# Epoch 16/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4751 - binary_accuracy: 0.7613
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4762 - binary_accuracy: 0.7640
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4753 - binary_accuracy: 0.7640
# Epoch 19/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4755 - binary_accuracy: 0.7627
# Epoch 20/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4777 - binary_accuracy: 0.7627
# Epoch 21/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4736 - binary_accuracy: 0.7627
# Epoch 22/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4733 - binary_accuracy: 0.7613
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4743 - binary_accuracy: 0.7587
# Epoch 24/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4738 - binary_accuracy: 0.7600
# Epoch 25/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4724 - binary_accuracy: 0.7627
# Epoch 26/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4725 - binary_accuracy: 0.7560
# Epoch 27/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4728 - binary_accuracy: 0.7573
# Epoch 28/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4730 - binary_accuracy: 0.7573
# Epoch 29/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4723 - binary_accuracy: 0.7587
# Epoch 30/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4715 - binary_accuracy: 0.7573
# Epoch 31/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7573
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4712 - binary_accuracy: 0.7573
# Epoch 33/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4714 - binary_accuracy: 0.7573
# Epoch 34/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4714 - binary_accuracy: 0.7533
# Epoch 35/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4718 - binary_accuracy: 0.7533
# Epoch 36/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4715 - binary_accuracy: 0.7547
# Epoch 37/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4707 - binary_accuracy: 0.7533
# Epoch 38/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4708 - binary_accuracy: 0.7573
# Epoch 39/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4699 - binary_accuracy: 0.7547
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4697 - binary_accuracy: 0.7560
# Epoch 41/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4697 - binary_accuracy: 0.7560
# Epoch 42/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4689 - binary_accuracy: 0.7547
# Epoch 43/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4693 - binary_accuracy: 0.7547
# Epoch 44/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4683 - binary_accuracy: 0.7587
# Epoch 45/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4685 - binary_accuracy: 0.7587
# Epoch 46/50
# 24/24 [==============================] - ETA: 0s - loss: 0.4241 - binary_accuracy: 0.875 - 0s 1ms/step - loss: 0.4691 - binary_accuracy: 0.7600
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4683 - binary_accuracy: 0.7600
# Epoch 48/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4679 - binary_accuracy: 0.7573
# Epoch 49/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4690 - binary_accuracy: 0.7587
# Epoch 50/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4685 - binary_accuracy: 0.7600
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4418 - binary_accuracy: 0.8120
# [0.4417950510978699, 0.8119999766349792]
# Wall time: 3.33 s

# %%
# %%time
moon_pytorch_nn_fit_score(X_train, Y_train, X_test, Y_test, 4)
# Out:
# PyTorch model training...
# Epoch: 1, training loss: 0.5353124943077564
# Epoch: 2, training loss: 0.4834142463793978
# Epoch: 3, training loss: 0.4811181257044276
# Epoch: 4, training loss: 0.4798423884928537
# Epoch: 5, training loss: 0.4787368101471414
# Epoch: 6, training loss: 0.4779279441749677
# Epoch: 7, training loss: 0.47721376549863875
# Epoch: 8, training loss: 0.4766861543529667
# Epoch: 9, training loss: 0.4762354297238247
# Epoch: 10, training loss: 0.47588652521922875
# Epoch: 11, training loss: 0.4754957226544308
# Epoch: 12, training loss: 0.475059388040759
# Epoch: 13, training loss: 0.47463862037841076
# Epoch: 14, training loss: 0.47410926307497236
# Epoch: 15, training loss: 0.473785139993454
# Epoch: 16, training loss: 0.4734239843557977
# Epoch: 17, training loss: 0.47316161707299764
# Epoch: 18, training loss: 0.47281510454788805
# Epoch: 19, training loss: 0.47252755468979013
# Epoch: 20, training loss: 0.4721867297012747
# Epoch: 21, training loss: 0.4720409071423346
# Epoch: 22, training loss: 0.47173934885739194
# Epoch: 23, training loss: 0.47134298384403034
# Epoch: 24, training loss: 0.4712602237056708
# Epoch: 25, training loss: 0.4709154395658601
# Epoch: 26, training loss: 0.47068053459282966
# Epoch: 27, training loss: 0.47050907780971224
# Epoch: 28, training loss: 0.47019230453751515
# Epoch: 29, training loss: 0.46990218621760144
# Epoch: 30, training loss: 0.469632128589903
# Epoch: 31, training loss: 0.4694075520571399
# Epoch: 32, training loss: 0.46926331152413814
# Epoch: 33, training loss: 0.4690319621577316
# Epoch: 34, training loss: 0.4687203607169213
# Epoch: 35, training loss: 0.4685255559098053
# Epoch: 36, training loss: 0.46835049636580517
# Epoch: 37, training loss: 0.46796147400261057
# Epoch: 38, training loss: 0.4681574443674569
# Epoch: 39, training loss: 0.4677959570840079
# Epoch: 40, training loss: 0.46746925042418297
# Epoch: 41, training loss: 0.4672585534460765
# Epoch: 42, training loss: 0.46714543834549843
# Epoch: 43, training loss: 0.4667670265493992
# Epoch: 44, training loss: 0.4666777296923877
# Epoch: 45, training loss: 0.4666197166621375
# Epoch: 46, training loss: 0.4663390380400233
# Epoch: 47, training loss: 0.46610738379657657
# Epoch: 48, training loss: 0.4660525313572143
# Epoch: 49, training loss: 0.46584170537480774
# Epoch: 50, training loss: 0.46570400362306585
#
#
# PyTorch model testing...
# Loss: 0.43969393690489234
# Accuracy: 0.836
# Wall time: 1min 6s

# %%
moon_accuracy_df
# Out:
#                             Dataset 1 Dataset 2 Dataset 3 Dataset 4
# Logistic Regression              0.88     0.884     0.852     0.828
# Decision Tree Classifier        0.992     0.864     0.764     0.708
# Linear SVC                       0.88     0.884     0.856     0.824
# KNN Classifier                  0.996     0.888     0.828     0.756
# Random Forest Classifier        0.988       0.9     0.804     0.728
# Gradient Boosting Classfier     0.992     0.896     0.816     0.796
# Keras NN                        0.992     0.892     0.848     0.812
# PyTorch NN                          1     0.888      0.82     0.836

# %% [markdown]
# Looking at the accuracy values across the moon datasets, the two neural networks performed consistently well in comparison to the other algorithms. Also, Logistic Regression and Linear SVC did surprisingly well considering the datasets are not linearly separable, and the decision boundaries for both algorithms are linear. Perhaps plotting the test datasets could bring more insight.
